# %% [markdown]
# ## Setting up the notebook

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.7 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (1.26.4)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.3.0)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 5.8 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1

# %%
import sacrebleu
import os

# %%
# mounting google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
source_code = 'eng'
target_code = 'tso'

# %% [markdown]
# ## baseline: BPE

# %%
ref = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/test.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpe/trained_model/post_process_translations_test'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_test'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpeDROP/trained_model/post_process_translations_test'

# %%
# !sacrebleu $ref -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-tso/bpe/trained_model/post_process_translations_test'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-tso/ulm/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-tso/bpeDROP/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-tso/bpe/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 34.98784065906264,
#             "p_value": null,
#             "mean": 35.003943612505445,
#             "ci": 1.1772606193351258
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-tso/ulm/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 34.81005112842165,
#             "p_value": 0.21578421578421578,
#             "mean": 34.81578650979813,
#             "ci": 1.1478657107256467
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-tso/bpeDROP/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 31.63069512210567,
#             "p_value": 0.000999000999000999,
#             "mean": 31.632500974222356,
#             "ci": 1.0893542151624054
#         }
#     }
# ]

# %%
ref1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref1.{target_code}'
ref2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref2.{target_code}'
ref3 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref3.{target_code}'
ref4 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref4.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpe/trained_model/post_process_translations_gtest'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_gtest'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpeDROP/trained_model/post_process_translations_gtest'

# %%
# !sacrebleu $ref1 $ref2 $ref3 $ref4 -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-tso/bpe/trained_model/post_process_translations_gtest'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-tso/ulm/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-tso/bpeDROP/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-tso/bpe/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 29.316659894162136,
#             "p_value": null,
#             "mean": 29.319585022303997,
#             "ci": 1.510540540653908
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-tso/ulm/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 27.916150254635888,
#             "p_value": 0.01098901098901099,
#             "mean": 27.9235726521424,
#             "ci": 1.597447095806535
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-tso/bpeDROP/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 31.072000756116864,
#             "p_value": 0.000999000999000999,
#             "mean": 31.07577104913646,
#             "ci": 1.5982643646492534
#         }
#     }
# ]

# %% [markdown]
# ## baseline: ULM

# %%
ref = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/test.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_test'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulmSR/trained_model/post_process_translations_test'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/target-tok/trained_model/post_process_translations_test'

# %%
# !sacrebleu $ref -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-tso/ulm/trained_model/post_process_translations_test'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-tso/ulmSR/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-tso/target-tok/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-tso/ulm/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 34.81005112842165,
#             "p_value": null,
#             "mean": 34.81578650979813,
#             "ci": 1.1478657107256467
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-tso/ulmSR/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 29.05147338255607,
#             "p_value": 0.000999000999000999,
#             "mean": 29.048606867324327,
#             "ci": 1.0536166875499422
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-tso/target-tok/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 35.02149756626115,
#             "p_value": 0.15584415584415584,
#             "mean": 35.026424574672056,
#             "ci": 1.214936142857308
#         }
#     }
# ]

# %%
ref1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref1.{target_code}'
ref2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref2.{target_code}'
ref3 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref3.{target_code}'
ref4 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref4.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_gtest'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulmSR/trained_model/post_process_translations_gtest'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/target-tok/trained_model/post_process_translations_gtest'

# %%
# !sacrebleu $ref1 $ref2 $ref3 $ref4 -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-tso/ulm/trained_model/post_process_translations_gtest'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-tso/ulmSR/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-tso/target-tok/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-tso/ulm/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 27.916150254635888,
#             "p_value": null,
#             "mean": 27.9235726521424,
#             "ci": 1.597447095806535
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-tso/ulmSR/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 30.1939982855478,
#             "p_value": 0.000999000999000999,
#             "mean": 30.18700934682683,
#             "ci": 1.6330782973720233
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-tso/target-tok/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 28.83495827592683,
#             "p_value": 0.013986013986013986,
#             "mean": 28.82563299017801,
#             "ci": 1.6287815328800281
#         }
#     }
# ]
