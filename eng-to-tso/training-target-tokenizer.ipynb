# %% [markdown]
# ## Setting up the notebook

# %%
# installing packages
# !pip install pip==24.0
# !pip install numpy==1.23.5
# !pip install tensorboardX
# !pip install sentencepiece
# Out:
# Requirement already satisfied: pip==24.0 in /usr/local/lib/python3.10/dist-packages (24.0)
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Collecting tensorboardX
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (24.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (3.20.3)
# Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)

# %%
# importing packages
import numpy
import os
import tensorboardX
import sentencepiece as spm

# %%
# mounting google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
source_code = 'eng'
target_code = 'tso'

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}')

# installing optok
#!git clone https://github.com/tatHi/optok4at.git
# %cd optok4at/machineTranslation/optok
# !pip install --editable .
# Out:
# /content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/optok
# Obtaining file:///content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/optok
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (1.23.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (0.60.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (1.13.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (6.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (4.66.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (2.5.0+cu121)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->optok_nmt==0.1.0) (0.43.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->optok_nmt==0.1.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->optok_nmt==0.1.0) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->optok_nmt==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->optok_nmt==0.1.0) (3.0.2)
# Installing collected packages: optok_nmt
#   Running setup.py develop for optok_nmt
# Successfully installed optok_nmt-0.1.0

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}')

# installing fairseq
# %cd optok4at/machineTranslation/fairseq
# !pip install --editable .
# Out:
# /content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/fairseq
# Obtaining file:///content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (1.17.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (3.0.11)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (0.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (1.23.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (2024.9.11)
# Collecting sacrebleu (from fairseq==0.9.0)
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (2.5.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (4.66.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->fairseq==0.9.0) (2.22)
# Collecting portalocker (from sacrebleu->fairseq==0.9.0)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu->fairseq==0.9.0) (0.9.0)
# Collecting colorama (from sacrebleu->fairseq==0.9.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu->fairseq==0.9.0) (5.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->fairseq==0.9.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->fairseq==0.9.0) (3.0.2)
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 9.1 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: fairseq
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.9.0-0.editable-cp310-cp310-linux_x86_64.whl size=7880 sha256=b3dad7bfc52a235210a2586bbeec24866f846198eddf5b9a3d5f9f3263e0eedd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ax4u7sf6/wheels/a1/d7/b7/e9f0596c65e36ad39bbb8410215c5fde672380ac5d46bf936c
# Successfully built fairseq
# Installing collected packages: portalocker, colorama, sacrebleu, fairseq
# Successfully installed colorama-0.4.6 fairseq-0.9.0 portalocker-2.10.1 sacrebleu-2.4.3

# %%
# installing youtokentome
# !pip install youtokentome
import youtokentome as yttm
# Out:
# Collecting youtokentome
#   Downloading youtokentome-1.0.6.tar.gz (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.10/dist-packages (from youtokentome) (8.1.7)
# Building wheels for collected packages: youtokentome
#   Building wheel for youtokentome (setup.py) ... done
#   Created wheel for youtokentome: filename=youtokentome-1.0.6-cp310-cp310-linux_x86_64.whl size=1951581 sha256=45fcf6e4c945a56e8ba9b3b08412ba81459b580da376163de8a7a156cb3428b3
#   Stored in directory: /root/.cache/pip/wheels/df/85/f8/301d2ba45f43f30bed2fe413efa760bc726b8b660ed9c2900c
# Successfully built youtokentome
# Installing collected packages: youtokentome
# Successfully installed youtokentome-1.0.6

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}')

# install multigram
#!git clone https://github.com/tatHi/multigram
# %cd multigram
# !pip install --editable .
# Out:
# /content/drive/MyDrive/Research/eng-to-tso/multigram
# Obtaining file:///content/drive/MyDrive/Research/eng-to-tso/multigram
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (1.23.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (0.60.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (1.13.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (6.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (4.66.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->multigram==0.1.0) (0.43.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->multigram==0.1.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->multigram==0.1.0) (3.5.0)
# Installing collected packages: multigram
#   Running setup.py develop for multigram
# Successfully installed multigram-0.1.0

# %% [markdown]
# ## Preparing the parallel corpus

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}/target-tok')

# %%
# prepare dictionary to be used by our nmt model
# !fairseq-preprocess -s eng -t tso \
--trainpref /content/drive/MyDrive/Research/eng-to-tso/ulm/data/train.ULM \
--validpref /content/drive/MyDrive/Research/eng-to-tso/ulm/data/val.ULM \
--testpref /content/drive/MyDrive/Research/eng-to-tso/ulm/data/test.ULM \
--joined-dictionary \
--srcdict /content/drive/MyDrive/Research/eng-to-tso/ulm/data-bin/dict.eng.txt \
--destdir data-bin \
--bpe 'sentencepiece' \
--workers 2
# Out:
# 2024-11-02 09:20:25 | INFO | fairseq_cli.preprocess | Namespace(no_progress_bar=False, log_interval=100, log_format=None, tensorboard_logdir='', seed=None, cpu=False, tpu=False, bf16=False, fp16=False, memory_efficient_bf16=False, memory_efficient_fp16=False, fp16_no_flatten_grads=False, fp16_init_scale=128, fp16_scale_window=None, fp16_scale_tolerance=0.0, min_loss_scale=0.0001, threshold_loss_scale=None, user_dir=None, empty_cache_freq=0, all_gather_list_size=16384, model_parallel_size=1, checkpoint_suffix='', quantization_config_path=None, profile=False, criterion='cross_entropy', tokenizer=None, bpe='sentencepiece', optimizer=None, lr_scheduler='fixed', scoring='bleu', task='translation', source_lang='eng', target_lang='tso', trainpref='/content/drive/MyDrive/Research/eng-to-tso/ulm/data/train.ULM', validpref='/content/drive/MyDrive/Research/eng-to-tso/ulm/data/val.ULM', testpref='/content/drive/MyDrive/Research/eng-to-tso/ulm/data/test.ULM', align_suffix=None, destdir='data-bin', thresholdtgt=0, thresholdsrc=0, tgtdict=None, srcdict='/content/drive/MyDrive/Research/eng-to-tso/ulm/data-bin/dict.eng.txt', nwordstgt=-1, nwordssrc=-1, alignfile=None, dataset_impl='mmap', joined_dictionary=True, only_source=False, padding_factor=8, workers=2)
# 2024-11-02 09:20:25 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 3992 types
# 2024-11-02 09:20:47 | INFO | fairseq_cli.preprocess | [eng] /content/drive/MyDrive/Research/eng-to-tso/ulm/data/train.ULM.eng: 149115 sents, 2194488 tokens, 9.11e-05% replaced by <unk>
# 2024-11-02 09:20:47 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 3992 types
# 2024-11-02 09:20:52 | INFO | fairseq_cli.preprocess | [eng] /content/drive/MyDrive/Research/eng-to-tso/ulm/data/val.ULM.eng: 43390 sents, 629580 tokens, 0.0% replaced by <unk>
# 2024-11-02 09:20:52 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 3992 types
# 2024-11-02 09:20:52 | INFO | fairseq_cli.preprocess | [eng] /content/drive/MyDrive/Research/eng-to-tso/ulm/data/test.ULM.eng: 3000 sents, 39466 tokens, 0.289% replaced by <unk>
# 2024-11-02 09:20:52 | INFO | fairseq_cli.preprocess | [tso] Dictionary: 3992 types
# 2024-11-02 09:21:15 | INFO | fairseq_cli.preprocess | [tso] /content/drive/MyDrive/Research/eng-to-tso/ulm/data/train.ULM.tso: 149115 sents, 2461330 tokens, 8.13e-05% replaced by <unk>
# 2024-11-02 09:21:15 | INFO | fairseq_cli.preprocess | [tso] Dictionary: 3992 types
# 2024-11-02 09:21:25 | INFO | fairseq_cli.preprocess | [tso] /content/drive/MyDrive/Research/eng-to-tso/ulm/data/val.ULM.tso: 43390 sents, 706111 tokens, 0.000142% replaced by <unk>
# 2024-11-02 09:21:25 | INFO | fairseq_cli.preprocess | [tso] Dictionary: 3992 types
# 2024-11-02 09:21:27 | INFO | fairseq_cli.preprocess | [tso] /content/drive/MyDrive/Research/eng-to-tso/ulm/data/test.ULM.tso: 3000 sents, 45714 tokens, 0.203% replaced by <unk>
# 2024-11-02 09:21:27 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to data-bin

# %% [markdown]
# ## Training Tokenizer

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}/target-tok')

# %%
# !fairseq-train \
--arch transformer_optok \
--activation-fn relu \
--share-decoder-input-output-embed \
--share-all-embeddings \
--encoder-layers 3 \
--encoder-attention-heads 4 \
--encoder-embed-dim 256 \
--encoder-ffn-embed-dim 1024 \
--decoder-layers 3 \
--decoder-attention-heads 4 \
--decoder-embed-dim 256 \
--decoder-ffn-embed-dim 1024 \
--dropout 0.25 \
--seed 2024 \
--optimizer 'adam' \
--adam-betas '(0.9, 0.999)' \
--lr-scheduler 'inverse_sqrt' \
--patience 5 \
--warmup-updates 1000 \
--criterion optok_pass_through \
--lr 0.0003 \
--weight-decay 0.0 \
--max-tokens 4096 \
--max-tokens-valid 3600 \
--required-batch-size-multiple 1 \
--update-freq 1 \
--max-epoch 30 \
--validate-interval 10 \
--save-interval 10 \
--best-checkpoint-metric 'loss' \
--log-interval 100 \
--curriculum 0 \
--save-dir checkpoints-target-tok \
--ddp-backend=no_c10d \
--optok-sp-src-path /content/drive/MyDrive/Research/eng-to-tso/ulm/data/joint.model \
--optok-sp-tgt-path /content/drive/MyDrive/Research/eng-to-tso/ulm/data/joint.model \
--optok-m 3 \
--sp-alpha 0.2 \
--optok-normal-enc \
--optok-fitto \
/content/drive/MyDrive/Research/eng-to-tso/target-tok/data-bin
# Out:
# 2024-11-02 16:16:17 | INFO | fairseq_cli.train | Namespace(no_progress_bar=False, log_interval=100, log_format=None, tensorboard_logdir='', seed=2024, cpu=False, tpu=False, bf16=False, fp16=False, memory_efficient_bf16=False, memory_efficient_fp16=False, fp16_no_flatten_grads=False, fp16_init_scale=128, fp16_scale_window=None, fp16_scale_tolerance=0.0, min_loss_scale=0.0001, threshold_loss_scale=None, user_dir=None, empty_cache_freq=0, all_gather_list_size=16384, model_parallel_size=1, checkpoint_suffix='', quantization_config_path=None, profile=False, criterion='optok_pass_through', tokenizer=None, bpe=None, optimizer='adam', lr_scheduler='inverse_sqrt', scoring='bleu', task='translation', num_workers=1, skip_invalid_size_inputs_valid_test=False, max_tokens=4096, max_sentences=None, required_batch_size_multiple=1, dataset_impl=None, data_buffer_size=10, train_subset='train', valid_subset='valid', validate_interval=10, validate_interval_updates=0, validate_after_updates=0, fixed_validation_seed=None, disable_validation=False, max_tokens_valid=3600, max_sentences_valid=None, curriculum=0, distributed_world_size=1, distributed_rank=0, distributed_backend='nccl', distributed_init_method=None, distributed_port=-1, device_id=0, distributed_no_spawn=False, ddp_backend='no_c10d', bucket_cap_mb=25, fix_batches_to_gpus=False, find_unused_parameters=False, fast_stat_sync=False, broadcast_buffers=False, distributed_wrapper='DDP', slowmo_momentum=None, slowmo_algorithm='LocalSGD', localsgd_frequency=3, nprocs_per_node=1, arch='transformer_optok', max_epoch=30, max_update=0, stop_time_hours=0, clip_norm=0.0, sentence_avg=False, update_freq=[1], lr=[0.0003], min_lr=-1, use_bmuf=False, save_dir='checkpoints-target-tok', restore_file='checkpoint_last.pt', finetune_from_model=None, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, optimizer_overrides='{}', save_interval=10, save_interval_updates=0, keep_interval_updates=-1, keep_last_epochs=-1, keep_best_checkpoints=-1, no_save=False, no_epoch_checkpoints=False, no_last_checkpoints=False, no_save_optimizer_state=False, best_checkpoint_metric='loss', maximize_best_checkpoint_metric=False, patience=5, no_token_positional_embeddings=False, no_cross_attention=False, cross_self_attention=False, encoder_layerdrop=0, decoder_layerdrop=0, encoder_layers_to_keep=None, decoder_layers_to_keep=None, quant_noise_pq=0, quant_noise_pq_block_size=8, quant_noise_scalar=0, optok_sp_src_path='/content/drive/MyDrive/Research/eng-to-tso/ulm/data/joint.model', optok_sp_tgt_path='/content/drive/MyDrive/Research/eng-to-tso/ulm/data/joint.model', sp_alpha=0.2, optok_m=3, optok_enc_mu=0.01, optok_dec_mu=0.01, optok_normal_enc=True, optok_normal_dec=False, optok_lmemb_enc=None, optok_lmemb_dec=None, optok_nlm_enc=None, optok_nlm_dec=None, adam_betas='(0.9, 0.999)', adam_eps=1e-08, weight_decay=0.0, use_old_adam=False, warmup_updates=1000, warmup_init_lr=-1, data='/content/drive/MyDrive/Research/eng-to-tso/target-tok/data-bin', source_lang=None, target_lang=None, load_alignments=False, left_pad_source='True', left_pad_target='False', max_source_positions=1024, max_target_positions=1024, upsample_primary=1, truncate_source=False, num_batch_buckets=0, eval_bleu=False, eval_bleu_detok='space', eval_bleu_detok_args=None, eval_tokenized_bleu=False, eval_bleu_remove_bpe=None, eval_bleu_args=None, eval_bleu_print_samples=False, activation_fn='relu', share_decoder_input_output_embed=True, share_all_embeddings=True, encoder_layers=3, encoder_attention_heads=4, encoder_embed_dim=256, encoder_ffn_embed_dim=1024, decoder_layers=3, decoder_attention_heads=4, decoder_embed_dim=256, decoder_ffn_embed_dim=1024, dropout=0.25, optok_fitto=True, no_seed_provided=False, encoder_embed_path=None, encoder_normalize_before=False, encoder_learned_pos=False, decoder_embed_path=None, decoder_normalize_before=False, decoder_learned_pos=False, attention_dropout=0.0, activation_dropout=0.0, adaptive_softmax_ ...
# 2024-11-02 16:16:17 | INFO | fairseq.tasks.translation | [eng] dictionary: 3992 types
# 2024-11-02 16:16:17 | INFO | fairseq.tasks.translation | [tso] dictionary: 3992 types
# 2024-11-02 16:16:17 | INFO | fairseq.data.data_utils | loaded 43390 examples from: /content/drive/MyDrive/Research/eng-to-tso/target-tok/data-bin/valid.eng-tso.eng
# 2024-11-02 16:16:17 | INFO | fairseq.data.data_utils | loaded 43390 examples from: /content/drive/MyDrive/Research/eng-to-tso/target-tok/data-bin/valid.eng-tso.tso
# 2024-11-02 16:16:17 | INFO | fairseq.tasks.translation | /content/drive/MyDrive/Research/eng-to-tso/target-tok/data-bin valid eng-tso 43390 examples
# 2024-11-02 16:16:17 | INFO | fairseq_cli.train | TransformerOpTokModel(
#   (encoder): TransformerEncoder(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(3992, 256, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerOpTokDecoder(
#     (optokDec): OpTokGen(
#       (lmEmbed): Embedding(3992, 64)
#       (encoder): TransformerDecoder(
#         (dropout_module): FairseqDropout()
#         (embed_tokens): Embedding(3992, 256, padding_idx=1)
#         (embed_positions): SinusoidalPositionalEmbedding()
#         (layers): ModuleList(
#           (0-2): 3 x TransformerDecoderLayer(
#             (dropout_module): FairseqDropout()
#             (self_attn): MultiheadAttention(
#               (dropout_module): FairseqDropout()
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (activation_dropout_module): FairseqDropout()
#             (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MultiheadAttention(
#               (dropout_module): FairseqDropout()
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=256, out_features=1024, bias=True)
#             (fc2): Linear(in_features=1024, out_features=256, bias=True)
#             (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (output_projection): Linear(in_features=256, out_features=3992, bias=False)
#       )
#       (nlm): UnigramNLM(
#         (scoreModule): Sequential(
#           (tanh1): Tanh()
#           (linear1): Linear(in_features=64, out_features=96, bias=True)
#           (tanh2): Tanh()
#           (linear2): Linear(in_features=96, out_features=1, bias=True)
#         )
#       )
#     )
#   )
# )
# 2024-11-02 16:16:17 | INFO | fairseq_cli.train | task: translation (TranslationTask)
# 2024-11-02 16:16:17 | INFO | fairseq_cli.train | model: transformer_optok (TransformerOpTokModel)
# 2024-11-02 16:16:17 | INFO | fairseq_cli.train | criterion: optok_pass_through (OpTokPassThroughCriterionModi)
# 2024-11-02 16:16:17 | INFO | fairseq_cli.train | num. model params: 6813377 (num. trained: 6813377)
# 2024-11-02 16:16:18 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.optokDec.encoder.embed_tokens.weight
# 2024-11-02 16:16:18 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.optokDec.encoder.output_projection.weight
# 2024-11-02 16:16:18 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2024-11-02 16:16:18 | INFO | fairseq.utils | rank   0: capabilities =  7.5  ; total memory = 14.748 GB ; name = Tesla T4
# 2024-11-02 16:16:18 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2024-11-02 16:16:18 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2024-11-02 16:16:18 | INFO | fairseq_cli.train | max tokens per GPU = 4096 and max sentences per GPU = None
# /content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/fairseq/fairseq/checkpoint_utils.py:208: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(
# 2024-11-02 16:16:18 | INFO | fairseq.trainer | NOTE: your device may support faster training with --fp16
# 2024-11-02 16:16:19 | INFO | fairseq.trainer | loaded checkpoint checkpoints-target-tok/checkpoint_last.pt (epoch 21 @ 13460 updates)
# 2024-11-02 16:16:19 | INFO | fairseq.trainer | loading train data for epoch 21
# 2024-11-02 16:16:19 | INFO | fairseq.data.data_utils | loaded 149115 examples from: /content/drive/MyDrive/Research/eng-to-tso/target-tok/data-bin/train.eng-tso.eng
# 2024-11-02 16:16:19 | INFO | fairseq.data.data_utils | loaded 149115 examples from: /content/drive/MyDrive/Research/eng-to-tso/target-tok/data-bin/train.eng-tso.tso
# 2024-11-02 16:16:19 | INFO | fairseq.tasks.translation | /content/drive/MyDrive/Research/eng-to-tso/target-tok/data-bin train eng-tso 149115 examples
# epoch 021:   0% 0/673 [00:00<?, ?it/s]2024-11-02 16:16:19 | INFO | fairseq.trainer | begin training epoch 21
# /content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/fairseq/fairseq_cli/train.py:231: UserWarning: Anomaly Detection has been enabled. This mode will increase the runtime and should only be enabled for debugging.
#   ), torch.autograd.detect_anomaly():
# /content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/optok/optok_nmt/unigramNLM.py:50: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(self.scoreModule(embed.weight.detach()).flatten())
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5849: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# /content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/optok/optok_nmt/optok4dec.py:123: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   lprobs = F.log_softmax(yss.view(-1, len(self.mlm.vocab)))
# /content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/fairseq/fairseq/utils.py:305: UserWarning: amp_C fused kernels unavailable, disabling multi_tensor_l2norm; you may get better performance by installing NVIDIA's apex library
#   warnings.warn(
# epoch 021:   0% 1/673 [00:04<47:56,  4.28s/it]/content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/fairseq/fairseq_cli/train.py:231: UserWarning: Anomaly Detection has been enabled. This mode will increase the runtime and should only be enabled for debugging.
#   ), torch.autograd.detect_anomaly():
# /content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/optok/optok_nmt/unigramNLM.py:50: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(self.scoreModule(embed.weight.detach()).flatten())
# 2024-11-02 16:37:00 | INFO | fairseq_cli.train | end of epoch 21 (average epoch stats below)
# 2024-11-02 16:37:00 | INFO | train | epoch 021 | loss 7.762 | ppl 217.09 | wps 2424.2 | ups 0.54 | wpb 4481.5 | bsz 221.6 | num_updates 14133 | lr 7.98002e-05 | gnorm 0.903 | train_wall 2465 | wall 0
# epoch 022:   0% 0/673 [00:00<?, ?it/s]2024-11-02 16:37:00 | INFO | fairseq.trainer | begin training epoch 22
# 2024-11-02 16:57:43 | INFO | fairseq_cli.train | end of epoch 22 (average epoch stats below)
# 2024-11-02 16:57:43 | INFO | train | epoch 022 | loss 7.691 | ppl 206.66 | wps 2426.6 | ups 0.54 | wpb 4481 | bsz 221.6 | num_updates 14806 | lr 7.79655e-05 | gnorm 0.901 | train_wall 1238 | wall 0
# epoch 023:   0% 0/673 [00:00<?, ?it/s]2024-11-02 16:57:43 | INFO | fairseq.trainer | begin training epoch 23
# 2024-11-02 17:18:27 | INFO | fairseq_cli.train | end of epoch 23 (average epoch stats below)
# 2024-11-02 17:18:27 | INFO | train | epoch 023 | loss 7.645 | ppl 200.11 | wps 2424.1 | ups 0.54 | wpb 4481.6 | bsz 221.6 | num_updates 15479 | lr 7.62517e-05 | gnorm 0.911 | train_wall 1240 | wall 0
# epoch 024:   0% 0/673 [00:00<?, ?it/s]2024-11-02 17:18:27 | INFO | fairseq.trainer | begin training epoch 24
# 2024-11-02 17:39:08 | INFO | fairseq_cli.train | end of epoch 24 (average epoch stats below)
# 2024-11-02 17:39:08 | INFO | train | epoch 024 | loss 7.606 | ppl 194.8 | wps 2432.4 | ups 0.54 | wpb 4483.7 | bsz 221.6 | num_updates 16152 | lr 7.46463e-05 | gnorm 0.908 | train_wall 1236 | wall 0
# epoch 025:   0% 0/673 [00:00<?, ?it/s]2024-11-02 17:39:08 | INFO | fairseq.trainer | begin training epoch 25
# 2024-11-02 17:59:46 | INFO | fairseq_cli.train | end of epoch 25 (average epoch stats below)
# 2024-11-02 17:59:46 | INFO | train | epoch 025 | loss 7.563 | ppl 189.05 | wps 2436.1 | ups 0.54 | wpb 4483.6 | bsz 221.6 | num_updates 16825 | lr 7.31381e-05 | gnorm 0.917 | train_wall 1234 | wall 0
# epoch 026:   0% 0/673 [00:00<?, ?it/s]2024-11-02 17:59:46 | INFO | fairseq.trainer | begin training epoch 26
# 2024-11-02 18:20:27 | INFO | fairseq_cli.train | end of epoch 26 (average epoch stats below)
# 2024-11-02 18:20:27 | INFO | train | epoch 026 | loss 7.525 | ppl 184.19 | wps 2431.6 | ups 0.54 | wpb 4482.9 | bsz 221.6 | num_updates 17498 | lr 7.17178e-05 | gnorm 0.909 | train_wall 1236 | wall 0
# epoch 027:   0% 0/673 [00:00<?, ?it/s]2024-11-02 18:20:27 | INFO | fairseq.trainer | begin training epoch 27
# 2024-11-02 18:41:02 | INFO | fairseq_cli.train | end of epoch 27 (average epoch stats below)
# 2024-11-02 18:41:02 | INFO | train | epoch 027 | loss 7.481 | ppl 178.62 | wps 2443.2 | ups 0.54 | wpb 4483.2 | bsz 221.6 | num_updates 18171 | lr 7.03772e-05 | gnorm 0.913 | train_wall 1231 | wall 0
# epoch 028:   0% 0/673 [00:00<?, ?it/s]2024-11-02 18:41:02 | INFO | fairseq.trainer | begin training epoch 28
# 2024-11-02 19:01:41 | INFO | fairseq_cli.train | end of epoch 28 (average epoch stats below)
# 2024-11-02 19:01:41 | INFO | train | epoch 028 | loss 7.452 | ppl 175.13 | wps 2434.7 | ups 0.54 | wpb 4481.4 | bsz 221.6 | num_updates 18844 | lr 6.9109e-05 | gnorm 0.922 | train_wall 1234 | wall 0
# epoch 029:   0% 0/673 [00:00<?, ?it/s]2024-11-02 19:01:41 | INFO | fairseq.trainer | begin training epoch 29
# 2024-11-02 19:22:21 | INFO | fairseq_cli.train | end of epoch 29 (average epoch stats below)
# 2024-11-02 19:22:21 | INFO | train | epoch 029 | loss 7.424 | ppl 171.75 | wps 2431.5 | ups 0.54 | wpb 4480.8 | bsz 221.6 | num_updates 19517 | lr 6.7907e-05 | gnorm 0.915 | train_wall 1236 | wall 0
# epoch 030:   0% 0/673 [00:00<?, ?it/s]2024-11-02 19:22:21 | INFO | fairseq.trainer | begin training epoch 30
# epoch 030: 100% 672/673 [20:34<00:01,  1.86s/it, loss=7.147, ppl=141.71, wps=2518.2, ups=0.55, wpb=4618.2, bsz=234.7, num_updates=20100, lr=6.6915e-05, gnorm=0.883, train_wall=183, wall=0]2024-11-02 19:42:57 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 030 | valid on 'valid' subset:   0% 0/246 [00:00<?, ?it/s]
# epoch 030 | valid on 'valid' subset:   0% 1/246 [00:00<00:48,  5.04it/s]
# epoch 030 | valid on 'valid' subset:   1% 3/246 [00:00<00:25,  9.44it/s]
# epoch 030 | valid on 'valid' subset:   2% 5/246 [00:00<00:21, 10.97it/s]
# epoch 030 | valid on 'valid' subset:   3% 7/246 [00:00<00:19, 12.35it/s]
# epoch 030 | valid on 'valid' subset:   4% 9/246 [00:00<00:20, 11.63it/s]
# epoch 030 | valid on 'valid' subset:   4% 11/246 [00:01<00:20, 11.50it/s]
# epoch 030 | valid on 'valid' subset:   5% 13/246 [00:01<00:18, 12.93it/s]
# epoch 030 | valid on 'valid' subset:   6% 15/246 [00:01<00:18, 12.63it/s]
# epoch 030 | valid on 'valid' subset:   7% 17/246 [00:01<00:17, 13.21it/s]
# epoch 030 | valid on 'valid' subset:   8% 19/246 [00:01<00:15, 14.65it/s]
# epoch 030 | valid on 'valid' subset:   9% 21/246 [00:01<00:15, 14.43it/s]
# epoch 030 | valid on 'valid' subset:   9% 23/246 [00:01<00:14, 15.17it/s]
# epoch 030 | valid on 'valid' subset:  10% 25/246 [00:01<00:13, 16.27it/s]
# epoch 030 | valid on 'valid' subset:  11% 27/246 [00:02<00:20, 10.51it/s]
# epoch 030 | valid on 'valid' subset:  12% 29/246 [00:02<00:18, 11.86it/s]
# epoch 030 | valid on 'valid' subset:  13% 31/246 [00:02<00:16, 13.37it/s]
# epoch 030 | valid on 'valid' subset:  13% 33/246 [00:02<00:14, 14.52it/s]
# epoch 030 | valid on 'valid' subset:  14% 35/246 [00:02<00:13, 15.23it/s]
# epoch 030 | valid on 'valid' subset:  15% 37/246 [00:02<00:12, 16.23it/s]
# epoch 030 | valid on 'valid' subset:  16% 39/246 [00:02<00:12, 17.08it/s]
# epoch 030 | valid on 'valid' subset:  17% 41/246 [00:03<00:12, 15.85it/s]
# epoch 030 | valid on 'valid' subset:  17% 43/246 [00:03<00:12, 15.85it/s]
# epoch 030 | valid on 'valid' subset:  18% 45/246 [00:03<00:12, 16.41it/s]
# epoch 030 | valid on 'valid' subset:  19% 47/246 [00:03<00:11, 17.19it/s]
# epoch 030 | valid on 'valid' subset:  20% 50/246 [00:03<00:10, 17.83it/s]
# epoch 030 | valid on 'valid' subset:  21% 52/246 [00:03<00:10, 17.71it/s]
# epoch 030 | valid on 'valid' subset:  22% 54/246 [00:03<00:10, 17.81it/s]
# epoch 030 | valid on 'valid' subset:  23% 56/246 [00:03<00:10, 17.69it/s]
# epoch 030 | valid on 'valid' subset:  24% 58/246 [00:03<00:10, 18.27it/s]
# epoch 030 | valid on 'valid' subset:  24% 60/246 [00:04<00:09, 18.70it/s]
# epoch 030 | valid on 'valid' subset:  25% 62/246 [00:04<00:10, 18.26it/s]
# epoch 030 | valid on 'valid' subset:  26% 64/246 [00:04<00:09, 18.27it/s]
# epoch 030 | valid on 'valid' subset:  27% 66/246 [00:04<00:10, 17.86it/s]
# epoch 030 | valid on 'valid' subset:  28% 68/246 [00:04<00:09, 18.22it/s]
# epoch 030 | valid on 'valid' subset:  29% 71/246 [00:04<00:09, 18.75it/s]
# epoch 030 | valid on 'valid' subset:  30% 74/246 [00:04<00:08, 19.55it/s]
# epoch 030 | valid on 'valid' subset:  31% 77/246 [00:04<00:08, 19.96it/s]
# epoch 030 | valid on 'valid' subset:  32% 79/246 [00:05<00:08, 19.61it/s]
# epoch 030 | valid on 'valid' subset:  33% 81/246 [00:05<00:08, 18.86it/s]
# epoch 030 | valid on 'valid' subset:  34% 83/246 [00:05<00:08, 18.99it/s]
# epoch 030 | valid on 'valid' subset:  35% 86/246 [00:05<00:08, 19.44it/s]
# epoch 030 | valid on 'valid' subset:  36% 89/246 [00:05<00:07, 20.31it/s]
# epoch 030 | valid on 'valid' subset:  37% 92/246 [00:05<00:07, 19.91it/s]
# epoch 030 | valid on 'valid' subset:  39% 95/246 [00:05<00:07, 20.07it/s]
# epoch 030 | valid on 'valid' subset:  40% 98/246 [00:06<00:07, 20.27it/s]
# epoch 030 | valid on 'valid' subset:  41% 101/246 [00:06<00:07, 20.63it/s]
# epoch 030 | valid on 'valid' subset:  42% 104/246 [00:06<00:07, 19.83it/s]
# epoch 030 | valid on 'valid' subset:  43% 107/246 [00:06<00:06, 20.19it/s]
# epoch 030 | valid on 'valid' subset:  45% 110/246 [00:06<00:06, 20.51it/s]
# epoch 030 | valid on 'valid' subset:  46% 113/246 [00:06<00:06, 20.13it/s]
# epoch 030 | valid on 'valid' subset:  47% 116/246 [00:06<00:06, 20.30it/s]
# epoch 030 | valid on 'valid' subset:  48% 119/246 [00:07<00:06, 20.78it/s]
# epoch 030 | valid on 'valid' subset:  50% 122/246 [00:07<00:05, 20.76it/s]
# epoch 030 | valid on 'valid' subset:  51% 125/246 [00:07<00:05, 20.41it/s]
# epoch 030 | valid on 'valid' subset:  52% 128/246 [00:07<00:05, 21.05it/s]
# epoch 030 | valid on 'valid' subset:  53% 131/246 [00:07<00:05, 20.94it/s]
# epoch 030 | valid on 'valid' subset:  54% 134/246 [00:07<00:05, 20.12it/s]
# epoch 030 | valid on 'valid' subset:  56% 137/246 [00:07<00:05, 18.73it/s]
# epoch 030 | valid on 'valid' subset:  57% 139/246 [00:08<00:05, 18.00it/s]
# epoch 030 | valid on 'valid' subset:  57% 141/246 [00:08<00:05, 17.96it/s]
# epoch 030 | valid on 'valid' subset:  58% 143/246 [00:08<00:05, 17.47it/s]
# epoch 030 | valid on 'valid' subset:  59% 145/246 [00:08<00:05, 16.92it/s]
# epoch 030 | valid on 'valid' subset:  60% 147/246 [00:08<00:05, 17.50it/s]
# epoch 030 | valid on 'valid' subset:  61% 149/246 [00:08<00:05, 17.57it/s]
# epoch 030 | valid on 'valid' subset:  61% 151/246 [00:08<00:05, 17.06it/s]
# epoch 030 | valid on 'valid' subset:  62% 153/246 [00:08<00:05, 16.53it/s]
# epoch 030 | valid on 'valid' subset:  63% 155/246 [00:09<00:05, 16.77it/s]
# epoch 030 | valid on 'valid' subset:  64% 157/246 [00:09<00:05, 16.43it/s]
# epoch 030 | valid on 'valid' subset:  65% 159/246 [00:09<00:05, 16.18it/s]
# epoch 030 | valid on 'valid' subset:  65% 161/246 [00:09<00:05, 16.87it/s]
# epoch 030 | valid on 'valid' subset:  66% 163/246 [00:09<00:05, 16.57it/s]
# epoch 030 | valid on 'valid' subset:  67% 165/246 [00:09<00:04, 16.72it/s]
# epoch 030 | valid on 'valid' subset:  68% 167/246 [00:09<00:04, 16.94it/s]
# epoch 030 | valid on 'valid' subset:  69% 169/246 [00:09<00:04, 16.66it/s]
# epoch 030 | valid on 'valid' subset:  70% 171/246 [00:09<00:04, 17.45it/s]
# epoch 030 | valid on 'valid' subset:  70% 173/246 [00:10<00:04, 17.73it/s]
# epoch 030 | valid on 'valid' subset:  71% 175/246 [00:10<00:04, 17.38it/s]
# epoch 030 | valid on 'valid' subset:  72% 177/246 [00:10<00:04, 17.18it/s]
# epoch 030 | valid on 'valid' subset:  73% 179/246 [00:10<00:03, 16.84it/s]
# epoch 030 | valid on 'valid' subset:  74% 181/246 [00:10<00:03, 16.64it/s]
# epoch 030 | valid on 'valid' subset:  74% 183/246 [00:10<00:03, 17.13it/s]
# epoch 030 | valid on 'valid' subset:  75% 185/246 [00:10<00:03, 16.42it/s]
# epoch 030 | valid on 'valid' subset:  76% 187/246 [00:10<00:03, 16.75it/s]
# epoch 030 | valid on 'valid' subset:  77% 189/246 [00:11<00:03, 17.19it/s]
# epoch 030 | valid on 'valid' subset:  78% 191/246 [00:11<00:03, 17.60it/s]
# epoch 030 | valid on 'valid' subset:  78% 193/246 [00:11<00:03, 16.84it/s]
# epoch 030 | valid on 'valid' subset:  79% 195/246 [00:11<00:03, 16.75it/s]
# epoch 030 | valid on 'valid' subset:  80% 197/246 [00:11<00:02, 16.90it/s]
# epoch 030 | valid on 'valid' subset:  81% 200/246 [00:11<00:02, 18.02it/s]
# epoch 030 | valid on 'valid' subset:  83% 203/246 [00:11<00:02, 19.56it/s]
# epoch 030 | valid on 'valid' subset:  84% 206/246 [00:11<00:01, 20.63it/s]
# epoch 030 | valid on 'valid' subset:  85% 209/246 [00:12<00:01, 21.68it/s]
# epoch 030 | valid on 'valid' subset:  86% 212/246 [00:12<00:01, 22.19it/s]
# epoch 030 | valid on 'valid' subset:  87% 215/246 [00:12<00:01, 22.70it/s]
# epoch 030 | valid on 'valid' subset:  89% 218/246 [00:12<00:01, 23.38it/s]
# epoch 030 | valid on 'valid' subset:  90% 221/246 [00:12<00:01, 23.24it/s]
# epoch 030 | valid on 'valid' subset:  91% 224/246 [00:12<00:00, 23.46it/s]
# epoch 030 | valid on 'valid' subset:  92% 227/246 [00:12<00:00, 23.63it/s]
# epoch 030 | valid on 'valid' subset:  93% 230/246 [00:12<00:00, 23.77it/s]
# epoch 030 | valid on 'valid' subset:  95% 233/246 [00:13<00:00, 23.84it/s]
# epoch 030 | valid on 'valid' subset:  96% 236/246 [00:13<00:00, 24.34it/s]
# epoch 030 | valid on 'valid' subset:  97% 239/246 [00:13<00:00, 24.48it/s]
# epoch 030 | valid on 'valid' subset:  98% 242/246 [00:13<00:00, 24.87it/s]
# epoch 030 | valid on 'valid' subset: 100% 245/246 [00:13<00:00, 24.33it/s]
#                                                                           2024-11-02 19:43:11 | INFO | valid | epoch 030 | valid on 'valid' subset | loss 8.609 | ppl 390.55 | wps 52638.2 | wpb 2870.4 | bsz 176.4 | num_updates 20190 | best_loss 8.609
# 2024-11-02 19:43:11 | INFO | fairseq_cli.train | begin save checkpoint
# 2024-11-02 19:43:12 | INFO | fairseq.checkpoint_utils | saved checkpoint checkpoints-target-tok/checkpoint30.pt (epoch 30 @ 20190 updates, score 8.609) (writing took 1.2424707700047293 seconds)
# /content/drive/MyDrive/Research/eng-to-tso/optok4at/machineTranslation/optok/optok_nmt/unigramNLM.py:46: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(self.scoreModule(embed.weight.detach()).flatten())
# >>> DUMP LEARNED LM AS MLM
# 2024-11-02 19:43:12 | INFO | fairseq_cli.train | end of epoch 30 (average epoch stats below)
# 2024-11-02 19:43:12 | INFO | train | epoch 030 | loss 7.394 | ppl 168.22 | wps 2412.1 | ups 0.54 | wpb 4483.6 | bsz 221.6 | num_updates 20190 | lr 6.67657e-05 | gnorm 0.918 | train_wall 1232 | wall 0
# 2024-11-02 19:43:12 | INFO | fairseq_cli.train | done training in 12413.1 seconds
