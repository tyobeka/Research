# %% [markdown]
# ## Setting up notebook

# %%
# installing packages
# !pip install pip==24.0
# !pip install numpy==1.23.5
# !pip install tensorboardX
# !pip install subword-nmt
# !pip install sentencepiece
# Out:
# Requirement already satisfied: pip==24.0 in /usr/local/lib/python3.10/dist-packages (24.0)
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Collecting tensorboardX
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (24.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (3.20.3)
# Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2
# Requirement already satisfied: subword-nmt in /usr/local/lib/python3.10/dist-packages (0.3.8)
# Requirement already satisfied: mock in /usr/local/lib/python3.10/dist-packages (from subword-nmt) (5.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from subword-nmt) (4.66.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)

# %%
# importing packages
import numpy
import os
import tensorboardX
import sentencepiece as spm

# %%
# mounting google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
source_code = 'eng'
target_code = 'nso'

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}')

# installing fairseq
# !git clone https://github.com/pytorch/fairseq.git
# %cd fairseq
# !pip install --editable ./
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 35379, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 35379 (delta 9), reused 36 (delta 9), pack-reused 35337 (from 1)
# Receiving objects: 100% (35379/35379), 25.47 MiB | 13.30 MiB/s, done.
# Resolving deltas: 100% (25537/25537), done.
# Updating files: 100% (1637/1637), done.
# /content/drive/MyDrive/Research/eng-to-nso/fairseq
# Obtaining file:///content/drive/MyDrive/Research/eng-to-nso/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (1.17.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (3.0.11)
# Collecting hydra-core<1.1,>=1.0.7 (from fairseq==0.12.2)
#   Downloading hydra_core-1.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting omegaconf<2.1 (from fairseq==0.12.2)
#   Downloading omegaconf-2.0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.21.3 in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (1.23.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (2024.9.11)
# Collecting sacrebleu>=1.4.12 (from fairseq==0.12.2)
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (2.4.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (4.66.5)
# Collecting bitarray (from fairseq==0.12.2)
#   Downloading bitarray-2.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: torchaudio>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (2.4.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (1.5.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from fairseq==0.12.2) (24.1)
# Collecting antlr4-python3-runtime==4.8 (from hydra-core<1.1,>=1.0.7->fairseq==0.12.2)
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.* in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.1->fairseq==0.12.2) (6.0.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.1->fairseq==0.12.2) (4.12.2)
# Collecting portalocker (from sacrebleu>=1.4.12->fairseq==0.12.2)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (0.9.0)
# Collecting colorama (from sacrebleu>=1.4.12->fairseq==0.12.2)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=1.4.12->fairseq==0.12.2) (4.9.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq==0.12.2) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq==0.12.2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->fairseq==0.12.2) (2024.6.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->fairseq==0.12.2) (2.22)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fairseq==0.12.2) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fairseq==0.12.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->fairseq==0.12.2) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->fairseq==0.12.2) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->fairseq==0.12.2) (1.3.0)
# Downloading hydra_core-1.0.7-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 4.8 MB/s eta 0:00:00
# Downloading omegaconf-2.0.6-py3-none-any.whl (36 kB)
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 3.7 MB/s eta 0:00:00
# Downloading bitarray-2.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.4/288.4 kB 5.5 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: fairseq, antlr4-python3-runtime
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.12.2-0.editable-cp310-cp310-linux_x86_64.whl size=9579 sha256=05d7045b72004491ac634a824f361ad788a75bbf249f544582cfc8cfc70f9305
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bvy8looa/wheels/26/b6/b0/27c000b9f95619eae152cc65edcf10b30500efb7e43dc6281f
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141213 sha256=9c23b8b442ca649784dd68d025c54ccaae161344e2ff01f207d17ed9d614e8a3
#   Stored in directory: /root/.cache/pip/wheels/a7/20/bd/e1477d664f22d99989fd28ee1a43d6633dddb5cb9e801350d5
# Successfully built fairseq antlr4-python3-runtime
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: bitarray, antlr4-python3-runtime, portalocker, omegaconf, colorama, sacrebleu, hydra-core, fairseq
# Successfully installed antlr4-python3-runtime-4.8 bitarray-2.9.3 colorama-0.4.6 fairseq-0.12.2 hydra-core-1.0.7 omegaconf-2.0.6 portalocker-2.10.1 sacrebleu-2.4.3

# %% [markdown]
# ## Tokenizing the data

# %%
train_source_path = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/train.{source_code}'
train_target_path = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/train.{target_code}'
val_source_path = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/val.{source_code}'
val_target_path = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/val.{target_code}'
test_source_path = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/test.{source_code}'
test_target_path = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/test.{target_code}'

# %% [markdown]
# ### BPE

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpe/data')

# %%
# learn joint vocabulary
# !subword-nmt learn-joint-bpe-and-vocab --input $train_source_path $train_target_path -s 4000 -o bpe.codes.4000 --write-vocabulary vocab.$source_code vocab.$target_code
# Out:
# 100% 4000/4000 [00:11<00:00, 356.13it/s]

# %%
# applying tokenization to training, validation and test sets
# !subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$source_code < $train_source_path > train.BPE.$source_code
# !subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$target_code < $train_target_path > train.BPE.$target_code

# !subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$source_code < $val_source_path > val.BPE.$source_code
# !subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$target_code < $val_target_path > val.BPE.$target_code

# !subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$source_code < $test_source_path > test.BPE.$source_code
# !subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$target_code < $test_target_path > test.BPE.$target_code

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpe')

# %%
# prepare dictionary to be used by our nmt model
# !fairseq-preprocess -s eng -t nso \
--trainpref data/train.BPE \
--validpref data/val.BPE \
--testpref data/test.BPE \
--joined-dictionary \
--destdir data-bin \
--bpe 'subword_nmt' \
--thresholdsrc 1 \
--thresholdtgt 1 \
--workers 2
# Out:
# 2024-10-15 10:12:25.023828: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-15 10:12:25.376763: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-15 10:12:25.473537: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-15 10:12:26.009735: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-15 10:12:28.756696: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/drive/MyDrive/Research/eng-to-nso/fairseq/fairseq/tasks/multires_hubert_pretraining.py:154: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   dictionaries = [ (Dictionary.load(f"{label_dir}/dict.{label}.txt") if label is not "" else None ) for label in self.cfg.labels]
# 2024-10-15 10:12:48 | INFO | fairseq_cli.preprocess | Namespace(no_progress_bar=False, log_interval=100, log_format=None, log_file=None, aim_repo=None, aim_run_hash=None, tensorboard_logdir=None, wandb_project=None, azureml_logging=False, seed=1, cpu=False, tpu=False, bf16=False, memory_efficient_bf16=False, fp16=False, memory_efficient_fp16=False, fp16_no_flatten_grads=False, fp16_init_scale=128, fp16_scale_window=None, fp16_scale_tolerance=0.0, on_cpu_convert_precision=False, min_loss_scale=0.0001, threshold_loss_scale=None, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, user_dir=None, empty_cache_freq=0, all_gather_list_size=16384, model_parallel_size=1, quantization_config_path=None, profile=False, reset_logging=False, suppress_crashes=False, use_plasma_view=False, plasma_path='/tmp/plasma', criterion='cross_entropy', tokenizer=None, bpe='subword_nmt', optimizer=None, lr_scheduler='fixed', scoring='bleu', task='translation', source_lang='eng', target_lang='nso', trainpref='data/train.BPE', validpref='data/val.BPE', testpref='data/test.BPE', align_suffix=None, destdir='data-bin', thresholdtgt=1, thresholdsrc=1, tgtdict=None, srcdict=None, nwordstgt=-1, nwordssrc=-1, alignfile=None, dataset_impl='mmap', joined_dictionary=True, only_source=False, padding_factor=8, workers=2, dict_only=False)
# 2024-10-15 10:12:50 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 4160 types
# 2024-10-15 10:12:58 | INFO | fairseq_cli.preprocess | [eng] data/train.BPE.eng: 20994 sents, 632125 tokens, 0.0% replaced (by <unk>)
# 2024-10-15 10:12:58 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 4160 types
# 2024-10-15 10:13:00 | INFO | fairseq_cli.preprocess | [eng] data/val.BPE.eng: 6336 sents, 185013 tokens, 0.0% replaced (by <unk>)
# 2024-10-15 10:13:00 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 4160 types
# 2024-10-15 10:13:01 | INFO | fairseq_cli.preprocess | [eng] data/test.BPE.eng: 3000 sents, 78436 tokens, 0.319% replaced (by <unk>)
# 2024-10-15 10:13:01 | INFO | fairseq_cli.preprocess | [nso] Dictionary: 4160 types
# 2024-10-15 10:13:07 | INFO | fairseq_cli.preprocess | [nso] data/train.BPE.nso: 20994 sents, 693708 tokens, 0.0% replaced (by <unk>)
# 2024-10-15 10:13:07 | INFO | fairseq_cli.preprocess | [nso] Dictionary: 4160 types
# 2024-10-15 10:13:10 | INFO | fairseq_cli.preprocess | [nso] data/val.BPE.nso: 6336 sents, 203103 tokens, 0.0% replaced (by <unk>)
# 2024-10-15 10:13:10 | INFO | fairseq_cli.preprocess | [nso] Dictionary: 4160 types
# 2024-10-15 10:13:12 | INFO | fairseq_cli.preprocess | [nso] data/test.BPE.nso: 3000 sents, 86441 tokens, 0.268% replaced (by <unk>)
# 2024-10-15 10:13:12 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to data-bin

# %% [markdown]
# ### ULM

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/data')

# %%
# learn joint vocabulary
spm.SentencePieceTrainer.train(f'--input={train_source_path},{train_target_path} --model_prefix=joint --model_type=unigram --vocab_size=4000 --character_coverage=1.0 --bos_id=0 --pad_id=1 --eos_id=2 --unk_id=3')

# %%
# applying tokenization to training, validation and test sets
sp = spm.SentencePieceProcessor(model_file='joint.model')

with open(train_source_path, 'r') as rf, open(f'train.ULM.{source_code}', 'w') as wf:
    for line in rf:
        wf.write(' '.join(sp.encode(line, out_type=str)) + '\n')

with open(train_target_path, 'r') as rf, open(f'train.ULM.{target_code}', 'w') as wf:
    for line in rf:
        wf.write(' '.join(sp.encode(line, out_type=str)) + '\n')

with open(val_source_path, 'r') as rf, open(f'val.ULM.{source_code}', 'w') as wf:
    for line in rf:
        wf.write(' '.join(sp.encode(line, out_type=str)) + '\n')

with open(val_target_path, 'r') as rf, open(f'val.ULM.{target_code}', 'w') as wf:
    for line in rf:
        wf.write(' '.join(sp.encode(line, out_type=str)) + '\n')

with open(test_source_path, 'r') as rf, open(f'test.ULM.{source_code}', 'w') as wf:
    for line in rf:
        wf.write(' '.join(sp.encode(line, out_type=str)) + '\n')

with open(test_target_path, 'r') as rf, open(f'test.ULM.{target_code}', 'w') as wf:
    for line in rf:
        wf.write(' '.join(sp.encode(line, out_type=str)) + '\n')

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm')

# %%
# prepare dictionary to be used by our nmt model
# !fairseq-preprocess -s eng -t nso \
--trainpref data/train.ULM \
--validpref data/val.ULM \
--testpref data/test.ULM \
--joined-dictionary \
--destdir data-bin \
--bpe 'sentencepiece' \
--thresholdsrc 1 \
--thresholdtgt 1 \
--workers 2
# Out:
# 2024-10-15 10:13:35.141225: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-15 10:13:35.165192: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-15 10:13:35.172200: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-15 10:13:35.189411: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-15 10:13:36.615833: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-10-15 10:13:43 | INFO | fairseq_cli.preprocess | Namespace(no_progress_bar=False, log_interval=100, log_format=None, log_file=None, aim_repo=None, aim_run_hash=None, tensorboard_logdir=None, wandb_project=None, azureml_logging=False, seed=1, cpu=False, tpu=False, bf16=False, memory_efficient_bf16=False, fp16=False, memory_efficient_fp16=False, fp16_no_flatten_grads=False, fp16_init_scale=128, fp16_scale_window=None, fp16_scale_tolerance=0.0, on_cpu_convert_precision=False, min_loss_scale=0.0001, threshold_loss_scale=None, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, user_dir=None, empty_cache_freq=0, all_gather_list_size=16384, model_parallel_size=1, quantization_config_path=None, profile=False, reset_logging=False, suppress_crashes=False, use_plasma_view=False, plasma_path='/tmp/plasma', criterion='cross_entropy', tokenizer=None, bpe='sentencepiece', optimizer=None, lr_scheduler='fixed', scoring='bleu', task='translation', source_lang='eng', target_lang='nso', trainpref='data/train.ULM', validpref='data/val.ULM', testpref='data/test.ULM', align_suffix=None, destdir='data-bin', thresholdtgt=1, thresholdsrc=1, tgtdict=None, srcdict=None, nwordstgt=-1, nwordssrc=-1, alignfile=None, dataset_impl='mmap', joined_dictionary=True, only_source=False, padding_factor=8, workers=2, dict_only=False)
# 2024-10-15 10:13:47 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 3992 types
# 2024-10-15 10:13:54 | INFO | fairseq_cli.preprocess | [eng] data/train.ULM.eng: 20994 sents, 628630 tokens, 0.0% replaced (by <unk>)
# 2024-10-15 10:13:54 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 3992 types
# 2024-10-15 10:13:57 | INFO | fairseq_cli.preprocess | [eng] data/val.ULM.eng: 6336 sents, 184103 tokens, 0.0% replaced (by <unk>)
# 2024-10-15 10:13:57 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 3992 types
# 2024-10-15 10:13:58 | INFO | fairseq_cli.preprocess | [eng] data/test.ULM.eng: 3000 sents, 75568 tokens, 3.83% replaced (by <unk>)
# 2024-10-15 10:13:58 | INFO | fairseq_cli.preprocess | [nso] Dictionary: 3992 types
# 2024-10-15 10:14:04 | INFO | fairseq_cli.preprocess | [nso] data/train.ULM.nso: 20994 sents, 699781 tokens, 0.0% replaced (by <unk>)
# 2024-10-15 10:14:04 | INFO | fairseq_cli.preprocess | [nso] Dictionary: 3992 types
# 2024-10-15 10:14:06 | INFO | fairseq_cli.preprocess | [nso] data/val.ULM.nso: 6336 sents, 205277 tokens, 0.0% replaced (by <unk>)
# 2024-10-15 10:14:06 | INFO | fairseq_cli.preprocess | [nso] Dictionary: 3992 types
# 2024-10-15 10:14:08 | INFO | fairseq_cli.preprocess | [nso] data/test.ULM.nso: 3000 sents, 84469 tokens, 3.41% replaced (by <unk>)
# 2024-10-15 10:14:08 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to data-bin
