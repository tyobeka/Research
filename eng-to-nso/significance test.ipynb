# %% [markdown]
# ## Setting up the notebook

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.6 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (1.26.4)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.3.0)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 3.7 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1

# %%
import sacrebleu

# %%
# mounting google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
source_code = 'eng'
target_code = 'nso'

# %% [markdown]
# ## baseline: BPE

# %%
ref = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/test.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpe/trained_model/post_process_translations_test'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_test'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpeDROP/trained_model/post_process_translations_test'

# %%
# !sacrebleu $ref -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-nso/bpe/trained_model/post_process_translations_test'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nso/ulm/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nso/bpeDROP/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-nso/bpe/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 18.157358729891225,
#             "p_value": null,
#             "mean": 18.158087857474225,
#             "ci": 0.7079962353317324
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-nso/ulm/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 17.846797500494777,
#             "p_value": 0.07392607392607392,
#             "mean": 17.850282056798445,
#             "ci": 0.6984671669192419
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-nso/bpeDROP/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 14.503374645852707,
#             "p_value": 0.000999000999000999,
#             "mean": 14.491618685425765,
#             "ci": 0.5688976523919091
#         }
#     }
# ]

# %%
ref1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref1.{target_code}'
ref2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref2.{target_code}'
ref3 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref3.{target_code}'
ref4 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref4.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpe/trained_model/post_process_translations_gtest'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_gtest'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpeDROP/trained_model/post_process_translations_gtest'

# %%
# !sacrebleu $ref1 $ref2 $ref3 $ref4 -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-nso/bpe/trained_model/post_process_translations_gtest'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nso/ulm/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nso/bpeDROP/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-nso/bpe/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 19.982519631579905,
#             "p_value": null,
#             "mean": 19.955601153653113,
#             "ci": 1.3395934744043174
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-nso/ulm/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 19.77583308242926,
#             "p_value": 0.23576423576423577,
#             "mean": 19.766242908952446,
#             "ci": 1.2744255988884508
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-nso/bpeDROP/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 18.647992165960588,
#             "p_value": 0.000999000999000999,
#             "mean": 18.662430228057485,
#             "ci": 1.280177883119288
#         }
#     }
# ]

# %% [markdown]
# ## baseline: ULM

# %%
ref = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/test.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_test'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulmSR/trained_model/post_process_translations_test'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/target-tok/trained_model/post_process_translations_test'

# %%
# !sacrebleu $ref -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-nso/ulm/trained_model/post_process_translations_test'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nso/ulmSR/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nso/target-tok/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-nso/ulm/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 17.846797500494777,
#             "p_value": null,
#             "mean": 17.850282056798445,
#             "ci": 0.6984671669192419
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-nso/ulmSR/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 11.222453195789022,
#             "p_value": 0.000999000999000999,
#             "mean": 11.214717117167886,
#             "ci": 0.5122137762113432
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-nso/target-tok/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 17.922853016579978,
#             "p_value": 0.24375624375624375,
#             "mean": 17.928965950590285,
#             "ci": 0.7091806630264035
#         }
#     }
# ]

# %%
ref1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref1.{target_code}'
ref2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref2.{target_code}'
ref3 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref3.{target_code}'
ref4 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref4.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_gtest'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulmSR/trained_model/post_process_translations_gtest'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/target-tok/trained_model/post_process_translations_gtest'

# %%
# !sacrebleu $ref1 $ref2 $ref3 $ref4 -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-nso/ulm/trained_model/post_process_translations_gtest'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nso/ulmSR/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nso/target-tok/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-nso/ulm/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 19.77583308242926,
#             "p_value": null,
#             "mean": 19.766242908952446,
#             "ci": 1.2744255988884508
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-nso/ulmSR/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 14.857661967980583,
#             "p_value": 0.000999000999000999,
#             "mean": 14.84395015983312,
#             "ci": 1.0995891967680427
#         }
#     },
#     {
#         "system": "/content/drive/MyDrive/Research/eng-to-nso/target-tok/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 20.014924751876027,
#             "p_value": 0.1968031968031968,
#             "mean": 20.014206194417625,
#             "ci": 1.2261940967994214
#         }
#     }
# ]
