# %% [markdown]
# ## Setting up the notebook

# %%
# installing packages
# !pip install pip==24.0
# !pip install numpy==1.23.5
# !pip install tensorboardX
# !pip install sentencepiece
# Out:
# Requirement already satisfied: pip==24.0 in /usr/local/lib/python3.10/dist-packages (24.0)
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Collecting tensorboardX
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (24.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (3.20.3)
# Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)

# %%
# importing packages
import numpy
import os
import tensorboardX
import sentencepiece as spm

# %%
# mounting google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
source_code = 'eng'
target_code = 'nde'

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}')

# installing optok
#!git clone https://github.com/tatHi/optok4at.git
# %cd optok4at/machineTranslation/optok
# !pip install --editable .
# Out:
# /content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/optok
# Obtaining file:///content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/optok
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (1.23.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (0.60.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (1.13.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (6.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (4.66.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from optok_nmt==0.1.0) (2.5.0+cu121)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->optok_nmt==0.1.0) (0.43.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->optok_nmt==0.1.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->optok_nmt==0.1.0) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->optok_nmt==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->optok_nmt==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->optok_nmt==0.1.0) (3.0.2)
# Installing collected packages: optok_nmt
#   Running setup.py develop for optok_nmt
# Successfully installed optok_nmt-0.1.0

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}')

# installing fairseq
# %cd optok4at/machineTranslation/fairseq
# !pip install --editable .
# Out:
# /content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/fairseq
# Obtaining file:///content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/fairseq
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cffi in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (1.17.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (3.0.11)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (0.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (1.23.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (2024.9.11)
# Collecting sacrebleu (from fairseq==0.9.0)
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (2.5.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fairseq==0.9.0) (4.66.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi->fairseq==0.9.0) (2.22)
# Collecting portalocker (from sacrebleu->fairseq==0.9.0)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu->fairseq==0.9.0) (0.9.0)
# Collecting colorama (from sacrebleu->fairseq==0.9.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu->fairseq==0.9.0) (5.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->fairseq==0.9.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->fairseq==0.9.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->fairseq==0.9.0) (3.0.2)
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 5.1 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: fairseq
#   Building editable for fairseq (pyproject.toml) ... done
#   Created wheel for fairseq: filename=fairseq-0.9.0-0.editable-cp310-cp310-linux_x86_64.whl size=7880 sha256=62374b5bc64aad4e130d75636a22cb68222b88a2bfd63a4490df3bae7ddcf73e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kitljw4n/wheels/20/e5/d0/08468bf4f0a5e80bf41d41aedae00d041c18cf6f26ba3b7068
# Successfully built fairseq
# Installing collected packages: portalocker, colorama, sacrebleu, fairseq
# Successfully installed colorama-0.4.6 fairseq-0.9.0 portalocker-2.10.1 sacrebleu-2.4.3

# %%
# installing youtokentome
# !pip install youtokentome
import youtokentome as yttm
# Out:
# Collecting youtokentome
#   Downloading youtokentome-1.0.6.tar.gz (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.10/dist-packages (from youtokentome) (8.1.7)
# Building wheels for collected packages: youtokentome
#   Building wheel for youtokentome (setup.py) ... done
#   Created wheel for youtokentome: filename=youtokentome-1.0.6-cp310-cp310-linux_x86_64.whl size=1951571 sha256=78b05da06f047eca8354e6ef66c5d11194bc5b3bf10b9af15b778858781081b4
#   Stored in directory: /root/.cache/pip/wheels/df/85/f8/301d2ba45f43f30bed2fe413efa760bc726b8b660ed9c2900c
# Successfully built youtokentome
# Installing collected packages: youtokentome
# Successfully installed youtokentome-1.0.6

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}')

# install multigram
#!git clone https://github.com/tatHi/multigram
# %cd multigram
# !pip install --editable .
# Out:
# /content/drive/MyDrive/Research/eng-to-nde/multigram
# Obtaining file:///content/drive/MyDrive/Research/eng-to-nde/multigram
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (1.23.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (0.60.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (1.13.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (6.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (1.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from multigram==0.1.0) (4.66.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->multigram==0.1.0) (0.43.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->multigram==0.1.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->multigram==0.1.0) (3.5.0)
# Installing collected packages: multigram
#   Running setup.py develop for multigram
# Successfully installed multigram-0.1.0

# %% [markdown]
# ## Preparing the parallel corpus

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}/target-tok')

# %%
# prepare dictionary to be used by our nmt model
# !fairseq-preprocess -s eng -t nde \
--trainpref /content/drive/MyDrive/Research/eng-to-nde/ulm/data/train.ULM \
--validpref /content/drive/MyDrive/Research/eng-to-nde/ulm/data/val.ULM \
--testpref /content/drive/MyDrive/Research/eng-to-nde/ulm/data/test.ULM \
--joined-dictionary \
--srcdict /content/drive/MyDrive/Research/eng-to-nde/ulm/data-bin/dict.eng.txt \
--destdir data-bin \
--bpe 'sentencepiece' \
--workers 2
# Out:
# 2024-11-04 08:31:01 | INFO | fairseq_cli.preprocess | Namespace(no_progress_bar=False, log_interval=100, log_format=None, tensorboard_logdir='', seed=None, cpu=False, tpu=False, bf16=False, fp16=False, memory_efficient_bf16=False, memory_efficient_fp16=False, fp16_no_flatten_grads=False, fp16_init_scale=128, fp16_scale_window=None, fp16_scale_tolerance=0.0, min_loss_scale=0.0001, threshold_loss_scale=None, user_dir=None, empty_cache_freq=0, all_gather_list_size=16384, model_parallel_size=1, checkpoint_suffix='', quantization_config_path=None, profile=False, criterion='cross_entropy', tokenizer=None, bpe='sentencepiece', optimizer=None, lr_scheduler='fixed', scoring='bleu', task='translation', source_lang='eng', target_lang='nde', trainpref='/content/drive/MyDrive/Research/eng-to-nde/ulm/data/train.ULM', validpref='/content/drive/MyDrive/Research/eng-to-nde/ulm/data/val.ULM', testpref='/content/drive/MyDrive/Research/eng-to-nde/ulm/data/test.ULM', align_suffix=None, destdir='data-bin', thresholdtgt=0, thresholdsrc=0, tgtdict=None, srcdict='/content/drive/MyDrive/Research/eng-to-nde/ulm/data-bin/dict.eng.txt', nwordstgt=-1, nwordssrc=-1, alignfile=None, dataset_impl='mmap', joined_dictionary=True, only_source=False, padding_factor=8, workers=2)
# 2024-11-04 08:31:01 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 3992 types
# 2024-11-04 08:31:23 | INFO | fairseq_cli.preprocess | [eng] /content/drive/MyDrive/Research/eng-to-nde/ulm/data/train.ULM.eng: 89783 sents, 2604172 tokens, 0.0% replaced by <unk>
# 2024-11-04 08:31:23 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 3992 types
# 2024-11-04 08:31:31 | INFO | fairseq_cli.preprocess | [eng] /content/drive/MyDrive/Research/eng-to-nde/ulm/data/val.ULM.eng: 23761 sents, 682361 tokens, 0.000147% replaced by <unk>
# 2024-11-04 08:31:31 | INFO | fairseq_cli.preprocess | [eng] Dictionary: 3992 types
# 2024-11-04 08:31:32 | INFO | fairseq_cli.preprocess | [eng] /content/drive/MyDrive/Research/eng-to-nde/ulm/data/test.ULM.eng: 3000 sents, 86502 tokens, 0.476% replaced by <unk>
# 2024-11-04 08:31:32 | INFO | fairseq_cli.preprocess | [nde] Dictionary: 3992 types
# 2024-11-04 08:31:55 | INFO | fairseq_cli.preprocess | [nde] /content/drive/MyDrive/Research/eng-to-nde/ulm/data/train.ULM.nde: 89783 sents, 2794108 tokens, 0.0% replaced by <unk>
# 2024-11-04 08:31:55 | INFO | fairseq_cli.preprocess | [nde] Dictionary: 3992 types
# 2024-11-04 08:32:03 | INFO | fairseq_cli.preprocess | [nde] /content/drive/MyDrive/Research/eng-to-nde/ulm/data/val.ULM.nde: 23761 sents, 731129 tokens, 0.000137% replaced by <unk>
# 2024-11-04 08:32:03 | INFO | fairseq_cli.preprocess | [nde] Dictionary: 3992 types
# 2024-11-04 08:32:04 | INFO | fairseq_cli.preprocess | [nde] /content/drive/MyDrive/Research/eng-to-nde/ulm/data/test.ULM.nde: 3000 sents, 92827 tokens, 0.332% replaced by <unk>
# 2024-11-04 08:32:04 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to data-bin

# %% [markdown]
# ## Training Tokenizer

# %%
# change working directory
os.chdir(f'/content/drive/MyDrive/Research/eng-to-{target_code}/target-tok')

# %%
# !fairseq-train \
--arch transformer_optok \
--activation-fn relu \
--share-decoder-input-output-embed \
--share-all-embeddings \
--encoder-layers 3 \
--encoder-attention-heads 4 \
--encoder-embed-dim 256 \
--encoder-ffn-embed-dim 1024 \
--decoder-layers 3 \
--decoder-attention-heads 4 \
--decoder-embed-dim 256 \
--decoder-ffn-embed-dim 1024 \
--dropout 0.25 \
--seed 2024 \
--optimizer 'adam' \
--adam-betas '(0.9, 0.999)' \
--lr-scheduler 'inverse_sqrt' \
--patience 5 \
--warmup-updates 1000 \
--criterion optok_pass_through \
--lr 0.0003 \
--weight-decay 0.0 \
--max-tokens 4096 \
--max-tokens-valid 3600 \
--required-batch-size-multiple 1 \
--update-freq 1 \
--max-epoch 30 \
--validate-interval 10 \
--save-interval 10 \
--best-checkpoint-metric 'loss' \
--log-interval 100 \
--curriculum 0 \
--save-dir checkpoints-target-tok \
--ddp-backend=no_c10d \
--optok-sp-src-path /content/drive/MyDrive/Research/eng-to-nde/ulm/data/joint.model \
--optok-sp-tgt-path /content/drive/MyDrive/Research/eng-to-nde/ulm/data/joint.model \
--optok-m 3 \
--sp-alpha 0.2 \
--optok-normal-enc \
--optok-fitto \
/content/drive/MyDrive/Research/eng-to-nde/target-tok/data-bin
# Out:
# 2024-11-04 08:40:55 | INFO | fairseq_cli.train | Namespace(no_progress_bar=False, log_interval=100, log_format=None, tensorboard_logdir='', seed=2024, cpu=False, tpu=False, bf16=False, fp16=False, memory_efficient_bf16=False, memory_efficient_fp16=False, fp16_no_flatten_grads=False, fp16_init_scale=128, fp16_scale_window=None, fp16_scale_tolerance=0.0, min_loss_scale=0.0001, threshold_loss_scale=None, user_dir=None, empty_cache_freq=0, all_gather_list_size=16384, model_parallel_size=1, checkpoint_suffix='', quantization_config_path=None, profile=False, criterion='optok_pass_through', tokenizer=None, bpe=None, optimizer='adam', lr_scheduler='inverse_sqrt', scoring='bleu', task='translation', num_workers=1, skip_invalid_size_inputs_valid_test=False, max_tokens=4096, max_sentences=None, required_batch_size_multiple=1, dataset_impl=None, data_buffer_size=10, train_subset='train', valid_subset='valid', validate_interval=10, validate_interval_updates=0, validate_after_updates=0, fixed_validation_seed=None, disable_validation=False, max_tokens_valid=3600, max_sentences_valid=None, curriculum=0, distributed_world_size=1, distributed_rank=0, distributed_backend='nccl', distributed_init_method=None, distributed_port=-1, device_id=0, distributed_no_spawn=False, ddp_backend='no_c10d', bucket_cap_mb=25, fix_batches_to_gpus=False, find_unused_parameters=False, fast_stat_sync=False, broadcast_buffers=False, distributed_wrapper='DDP', slowmo_momentum=None, slowmo_algorithm='LocalSGD', localsgd_frequency=3, nprocs_per_node=1, arch='transformer_optok', max_epoch=30, max_update=0, stop_time_hours=0, clip_norm=0.0, sentence_avg=False, update_freq=[1], lr=[0.0003], min_lr=-1, use_bmuf=False, save_dir='checkpoints-target-tok', restore_file='checkpoint_last.pt', finetune_from_model=None, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, optimizer_overrides='{}', save_interval=10, save_interval_updates=0, keep_interval_updates=-1, keep_last_epochs=-1, keep_best_checkpoints=-1, no_save=False, no_epoch_checkpoints=False, no_last_checkpoints=False, no_save_optimizer_state=False, best_checkpoint_metric='loss', maximize_best_checkpoint_metric=False, patience=5, no_token_positional_embeddings=False, no_cross_attention=False, cross_self_attention=False, encoder_layerdrop=0, decoder_layerdrop=0, encoder_layers_to_keep=None, decoder_layers_to_keep=None, quant_noise_pq=0, quant_noise_pq_block_size=8, quant_noise_scalar=0, optok_sp_src_path='/content/drive/MyDrive/Research/eng-to-nde/ulm/data/joint.model', optok_sp_tgt_path='/content/drive/MyDrive/Research/eng-to-nde/ulm/data/joint.model', sp_alpha=0.2, optok_m=3, optok_enc_mu=0.01, optok_dec_mu=0.01, optok_normal_enc=True, optok_normal_dec=False, optok_lmemb_enc=None, optok_lmemb_dec=None, optok_nlm_enc=None, optok_nlm_dec=None, adam_betas='(0.9, 0.999)', adam_eps=1e-08, weight_decay=0.0, use_old_adam=False, warmup_updates=1000, warmup_init_lr=-1, data='/content/drive/MyDrive/Research/eng-to-nde/target-tok/data-bin', source_lang=None, target_lang=None, load_alignments=False, left_pad_source='True', left_pad_target='False', max_source_positions=1024, max_target_positions=1024, upsample_primary=1, truncate_source=False, num_batch_buckets=0, eval_bleu=False, eval_bleu_detok='space', eval_bleu_detok_args=None, eval_tokenized_bleu=False, eval_bleu_remove_bpe=None, eval_bleu_args=None, eval_bleu_print_samples=False, activation_fn='relu', share_decoder_input_output_embed=True, share_all_embeddings=True, encoder_layers=3, encoder_attention_heads=4, encoder_embed_dim=256, encoder_ffn_embed_dim=1024, decoder_layers=3, decoder_attention_heads=4, decoder_embed_dim=256, decoder_ffn_embed_dim=1024, dropout=0.25, optok_fitto=True, no_seed_provided=False, encoder_embed_path=None, encoder_normalize_before=False, encoder_learned_pos=False, decoder_embed_path=None, decoder_normalize_before=False, decoder_learned_pos=False, attention_dropout=0.0, activation_dropout=0.0, adaptive_softmax_ ...
# 2024-11-04 08:40:56 | INFO | fairseq.tasks.translation | [eng] dictionary: 3992 types
# 2024-11-04 08:40:56 | INFO | fairseq.tasks.translation | [nde] dictionary: 3992 types
# 2024-11-04 08:40:57 | INFO | fairseq.data.data_utils | loaded 23761 examples from: /content/drive/MyDrive/Research/eng-to-nde/target-tok/data-bin/valid.eng-nde.eng
# 2024-11-04 08:40:58 | INFO | fairseq.data.data_utils | loaded 23761 examples from: /content/drive/MyDrive/Research/eng-to-nde/target-tok/data-bin/valid.eng-nde.nde
# 2024-11-04 08:40:58 | INFO | fairseq.tasks.translation | /content/drive/MyDrive/Research/eng-to-nde/target-tok/data-bin valid eng-nde 23761 examples
# 2024-11-04 08:40:59 | INFO | fairseq_cli.train | TransformerOpTokModel(
#   (encoder): TransformerEncoder(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(3992, 256, padding_idx=1)
#     (embed_positions): SinusoidalPositionalEmbedding()
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=256, out_features=1024, bias=True)
#         (fc2): Linear(in_features=1024, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerOpTokDecoder(
#     (optokDec): OpTokGen(
#       (lmEmbed): Embedding(3992, 64)
#       (encoder): TransformerDecoder(
#         (dropout_module): FairseqDropout()
#         (embed_tokens): Embedding(3992, 256, padding_idx=1)
#         (embed_positions): SinusoidalPositionalEmbedding()
#         (layers): ModuleList(
#           (0-2): 3 x TransformerDecoderLayer(
#             (dropout_module): FairseqDropout()
#             (self_attn): MultiheadAttention(
#               (dropout_module): FairseqDropout()
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (activation_dropout_module): FairseqDropout()
#             (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (encoder_attn): MultiheadAttention(
#               (dropout_module): FairseqDropout()
#               (k_proj): Linear(in_features=256, out_features=256, bias=True)
#               (v_proj): Linear(in_features=256, out_features=256, bias=True)
#               (q_proj): Linear(in_features=256, out_features=256, bias=True)
#               (out_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=256, out_features=1024, bias=True)
#             (fc2): Linear(in_features=1024, out_features=256, bias=True)
#             (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (output_projection): Linear(in_features=256, out_features=3992, bias=False)
#       )
#       (nlm): UnigramNLM(
#         (scoreModule): Sequential(
#           (tanh1): Tanh()
#           (linear1): Linear(in_features=64, out_features=96, bias=True)
#           (tanh2): Tanh()
#           (linear2): Linear(in_features=96, out_features=1, bias=True)
#         )
#       )
#     )
#   )
# )
# 2024-11-04 08:40:59 | INFO | fairseq_cli.train | task: translation (TranslationTask)
# 2024-11-04 08:40:59 | INFO | fairseq_cli.train | model: transformer_optok (TransformerOpTokModel)
# 2024-11-04 08:40:59 | INFO | fairseq_cli.train | criterion: optok_pass_through (OpTokPassThroughCriterionModi)
# 2024-11-04 08:40:59 | INFO | fairseq_cli.train | num. model params: 6813377 (num. trained: 6813377)
# 2024-11-04 08:40:59 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.optokDec.encoder.embed_tokens.weight
# 2024-11-04 08:40:59 | INFO | fairseq.trainer | detected shared parameter: encoder.embed_tokens.weight <- decoder.optokDec.encoder.output_projection.weight
# 2024-11-04 08:40:59 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2024-11-04 08:40:59 | INFO | fairseq.utils | rank   0: capabilities =  7.5  ; total memory = 14.748 GB ; name = Tesla T4
# 2024-11-04 08:40:59 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2024-11-04 08:40:59 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2024-11-04 08:40:59 | INFO | fairseq_cli.train | max tokens per GPU = 4096 and max sentences per GPU = None
# 2024-11-04 08:40:59 | INFO | fairseq.trainer | no existing checkpoint found checkpoints-target-tok/checkpoint_last.pt
# 2024-11-04 08:40:59 | INFO | fairseq.trainer | loading train data for epoch 1
# 2024-11-04 08:41:00 | INFO | fairseq.data.data_utils | loaded 89783 examples from: /content/drive/MyDrive/Research/eng-to-nde/target-tok/data-bin/train.eng-nde.eng
# 2024-11-04 08:41:01 | INFO | fairseq.data.data_utils | loaded 89783 examples from: /content/drive/MyDrive/Research/eng-to-nde/target-tok/data-bin/train.eng-nde.nde
# 2024-11-04 08:41:01 | INFO | fairseq.tasks.translation | /content/drive/MyDrive/Research/eng-to-nde/target-tok/data-bin train eng-nde 89783 examples
# 2024-11-04 08:41:01 | INFO | fairseq.trainer | NOTE: your device may support faster training with --fp16
# run fit to for decoder
# >>> LOAD SENTENCEPIECE MODEL
# vocab diff
# {'madeupword0000', 'madeupword0001'}
# set vocab diff as small value, exp(-30)
# set scores of special tokens as exp(-30)
# >>> FIT UNIGRAM NLM TO PRETRAINED THETA
# /content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/optok/optok_nmt/unigramNLM.py:50: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(self.scoreModule(embed.weight.detach()).flatten())
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:3369: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# 10855/100000: 0.0000001000
# DONE,
# LOSS= tensor(9.9993e-08, device='cuda:0', grad_fn=<MeanBackward0>)
# TIME: 17.884138345718384
# epoch 001:   0% 0/777 [00:00<?, ?it/s]2024-11-04 08:41:21 | INFO | fairseq.trainer | begin training epoch 1
# /content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/fairseq/fairseq_cli/train.py:231: UserWarning: Anomaly Detection has been enabled. This mode will increase the runtime and should only be enabled for debugging.
#   ), torch.autograd.detect_anomaly():
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5849: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# /content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/optok/optok_nmt/optok4dec.py:123: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   lprobs = F.log_softmax(yss.view(-1, len(self.mlm.vocab)))
# /content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/fairseq/fairseq/utils.py:305: UserWarning: amp_C fused kernels unavailable, disabling multi_tensor_l2norm; you may get better performance by installing NVIDIA's apex library
#   warnings.warn(
# epoch 001:   0% 1/777 [00:07<1:39:32,  7.70s/it]/content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/fairseq/fairseq_cli/train.py:231: UserWarning: Anomaly Detection has been enabled. This mode will increase the runtime and should only be enabled for debugging.
#   ), torch.autograd.detect_anomaly():
# /content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/optok/optok_nmt/unigramNLM.py:50: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(self.scoreModule(embed.weight.detach()).flatten())
# 2024-11-04 09:05:11 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2024-11-04 09:05:11 | INFO | train | epoch 001 | loss 16.394 | ppl 86087.1 | wps 2623.7 | ups 0.55 | wpb 4810.1 | bsz 115.6 | num_updates 777 | lr 0.0002331 | gnorm 0.904 | train_wall 1424 | wall 1451
# epoch 002:   0% 0/777 [00:00<?, ?it/s]2024-11-04 09:05:11 | INFO | fairseq.trainer | begin training epoch 2
# 2024-11-04 09:28:51 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2024-11-04 09:28:51 | INFO | train | epoch 002 | loss 12.821 | ppl 7234.63 | wps 2632.1 | ups 0.55 | wpb 4812.8 | bsz 115.6 | num_updates 1554 | lr 0.000240655 | gnorm 0.697 | train_wall 1415 | wall 2872
# epoch 003:   0% 0/777 [00:00<?, ?it/s]2024-11-04 09:28:51 | INFO | fairseq.trainer | begin training epoch 3
# 2024-11-04 09:52:36 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2024-11-04 09:52:36 | INFO | train | epoch 003 | loss 11.408 | ppl 2717.39 | wps 2625.2 | ups 0.55 | wpb 4812.5 | bsz 115.6 | num_updates 2331 | lr 0.000196494 | gnorm 0.644 | train_wall 1419 | wall 4297
# epoch 004:   0% 0/777 [00:00<?, ?it/s]2024-11-04 09:52:36 | INFO | fairseq.trainer | begin training epoch 4
# 2024-11-04 10:16:07 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2024-11-04 10:16:07 | INFO | train | epoch 004 | loss 10.762 | ppl 1736.68 | wps 2649.7 | ups 0.55 | wpb 4813.9 | bsz 115.6 | num_updates 3108 | lr 0.000170169 | gnorm 0.649 | train_wall 1406 | wall 5708
# epoch 005:   0% 0/777 [00:00<?, ?it/s]2024-11-04 10:16:07 | INFO | fairseq.trainer | begin training epoch 5
# 2024-11-04 10:39:36 | INFO | fairseq_cli.train | end of epoch 5 (average epoch stats below)
# 2024-11-04 10:39:36 | INFO | train | epoch 005 | loss 10.315 | ppl 1274.07 | wps 2655.1 | ups 0.55 | wpb 4814.3 | bsz 115.6 | num_updates 3885 | lr 0.000152204 | gnorm 0.656 | train_wall 1404 | wall 7117
# epoch 006:   0% 0/777 [00:00<?, ?it/s]2024-11-04 10:39:36 | INFO | fairseq.trainer | begin training epoch 6
# 2024-11-04 11:03:03 | INFO | fairseq_cli.train | end of epoch 6 (average epoch stats below)
# 2024-11-04 11:03:03 | INFO | train | epoch 006 | loss 9.992 | ppl 1018.03 | wps 2656.9 | ups 0.55 | wpb 4811.6 | bsz 115.6 | num_updates 4662 | lr 0.000138943 | gnorm 0.686 | train_wall 1402 | wall 8524
# epoch 007:   0% 0/777 [00:00<?, ?it/s]2024-11-04 11:03:03 | INFO | fairseq.trainer | begin training epoch 7
# 2024-11-04 11:26:44 | INFO | fairseq_cli.train | end of epoch 7 (average epoch stats below)
# 2024-11-04 11:26:44 | INFO | train | epoch 007 | loss 9.745 | ppl 858.03 | wps 2631.8 | ups 0.55 | wpb 4812.7 | bsz 115.6 | num_updates 5439 | lr 0.000128636 | gnorm 0.696 | train_wall 1416 | wall 9945
# epoch 008:   0% 0/777 [00:00<?, ?it/s]2024-11-04 11:26:44 | INFO | fairseq.trainer | begin training epoch 8
# 2024-11-04 11:50:19 | INFO | fairseq_cli.train | end of epoch 8 (average epoch stats below)
# 2024-11-04 11:50:19 | INFO | train | epoch 008 | loss 9.547 | ppl 748.21 | wps 2643.5 | ups 0.55 | wpb 4812.7 | bsz 115.6 | num_updates 6216 | lr 0.000120328 | gnorm 0.73 | train_wall 1409 | wall 11360
# epoch 009:   0% 0/777 [00:00<?, ?it/s]2024-11-04 11:50:19 | INFO | fairseq.trainer | begin training epoch 9
# 2024-11-04 12:13:55 | INFO | fairseq_cli.train | end of epoch 9 (average epoch stats below)
# 2024-11-04 12:13:55 | INFO | train | epoch 009 | loss 9.386 | ppl 669.16 | wps 2638.8 | ups 0.55 | wpb 4809.5 | bsz 115.6 | num_updates 6993 | lr 0.000113446 | gnorm 0.731 | train_wall 1411 | wall 12776
# epoch 010:   0% 0/777 [00:00<?, ?it/s]2024-11-04 12:13:55 | INFO | fairseq.trainer | begin training epoch 10
# epoch 010: 100% 776/777 [23:29<00:01,  1.79s/it, loss=9.042, ppl=527.19, wps=2794.4, ups=0.55, wpb=5085.6, bsz=123.6, num_updates=7700, lr=0.000108112, gnorm=0.764, train_wall=181, wall=14060]2024-11-04 12:37:26 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 010 | valid on 'valid' subset:   0% 0/262 [00:00<?, ?it/s]
# epoch 010 | valid on 'valid' subset:   0% 1/262 [00:00<00:41,  6.23it/s]
# epoch 010 | valid on 'valid' subset:   1% 3/262 [00:00<00:23, 10.81it/s]
# epoch 010 | valid on 'valid' subset:   2% 5/262 [00:00<00:19, 13.38it/s]
# epoch 010 | valid on 'valid' subset:   3% 7/262 [00:00<00:17, 14.25it/s]
# epoch 010 | valid on 'valid' subset:   3% 9/262 [00:00<00:16, 15.68it/s]
# epoch 010 | valid on 'valid' subset:   5% 12/262 [00:00<00:14, 17.74it/s]
# epoch 010 | valid on 'valid' subset:   6% 15/262 [00:00<00:12, 19.07it/s]
# epoch 010 | valid on 'valid' subset:   7% 18/262 [00:01<00:12, 19.56it/s]
# epoch 010 | valid on 'valid' subset:   8% 20/262 [00:01<00:12, 19.24it/s]
# epoch 010 | valid on 'valid' subset:   8% 22/262 [00:01<00:12, 19.26it/s]
# epoch 010 | valid on 'valid' subset:  10% 25/262 [00:01<00:11, 20.25it/s]
# epoch 010 | valid on 'valid' subset:  11% 28/262 [00:01<00:11, 20.29it/s]
# epoch 010 | valid on 'valid' subset:  12% 31/262 [00:01<00:11, 20.36it/s]
# epoch 010 | valid on 'valid' subset:  13% 34/262 [00:01<00:10, 20.96it/s]
# epoch 010 | valid on 'valid' subset:  14% 37/262 [00:01<00:10, 20.92it/s]
# epoch 010 | valid on 'valid' subset:  15% 40/262 [00:02<00:10, 20.62it/s]
# epoch 010 | valid on 'valid' subset:  16% 43/262 [00:02<00:10, 21.01it/s]
# epoch 010 | valid on 'valid' subset:  18% 46/262 [00:02<00:10, 21.01it/s]
# epoch 010 | valid on 'valid' subset:  19% 49/262 [00:02<00:10, 20.95it/s]
# epoch 010 | valid on 'valid' subset:  20% 52/262 [00:02<00:09, 21.35it/s]
# epoch 010 | valid on 'valid' subset:  21% 55/262 [00:02<00:09, 21.44it/s]
# epoch 010 | valid on 'valid' subset:  22% 58/262 [00:02<00:09, 21.77it/s]
# epoch 010 | valid on 'valid' subset:  23% 61/262 [00:03<00:09, 21.20it/s]
# epoch 010 | valid on 'valid' subset:  24% 64/262 [00:03<00:09, 21.65it/s]
# epoch 010 | valid on 'valid' subset:  26% 67/262 [00:03<00:09, 21.41it/s]
# epoch 010 | valid on 'valid' subset:  27% 70/262 [00:03<00:08, 21.54it/s]
# epoch 010 | valid on 'valid' subset:  28% 73/262 [00:03<00:08, 21.31it/s]
# epoch 010 | valid on 'valid' subset:  29% 76/262 [00:03<00:08, 21.58it/s]
# epoch 010 | valid on 'valid' subset:  30% 79/262 [00:03<00:08, 21.76it/s]
# epoch 010 | valid on 'valid' subset:  31% 82/262 [00:04<00:08, 22.08it/s]
# epoch 010 | valid on 'valid' subset:  32% 85/262 [00:04<00:08, 22.06it/s]
# epoch 010 | valid on 'valid' subset:  34% 88/262 [00:04<00:07, 21.88it/s]
# epoch 010 | valid on 'valid' subset:  35% 91/262 [00:04<00:07, 22.20it/s]
# epoch 010 | valid on 'valid' subset:  36% 94/262 [00:04<00:07, 22.07it/s]
# epoch 010 | valid on 'valid' subset:  37% 97/262 [00:04<00:07, 22.57it/s]
# epoch 010 | valid on 'valid' subset:  38% 100/262 [00:04<00:07, 22.42it/s]
# epoch 010 | valid on 'valid' subset:  39% 103/262 [00:05<00:06, 22.83it/s]
# epoch 010 | valid on 'valid' subset:  40% 106/262 [00:05<00:06, 22.57it/s]
# epoch 010 | valid on 'valid' subset:  42% 109/262 [00:05<00:06, 22.13it/s]
# epoch 010 | valid on 'valid' subset:  43% 112/262 [00:05<00:06, 22.16it/s]
# epoch 010 | valid on 'valid' subset:  44% 115/262 [00:05<00:06, 22.40it/s]
# epoch 010 | valid on 'valid' subset:  45% 118/262 [00:05<00:06, 22.43it/s]
# epoch 010 | valid on 'valid' subset:  46% 121/262 [00:05<00:06, 22.64it/s]
# epoch 010 | valid on 'valid' subset:  47% 124/262 [00:05<00:06, 22.75it/s]
# epoch 010 | valid on 'valid' subset:  48% 127/262 [00:06<00:05, 22.58it/s]
# epoch 010 | valid on 'valid' subset:  50% 130/262 [00:06<00:05, 22.52it/s]
# epoch 010 | valid on 'valid' subset:  51% 133/262 [00:06<00:05, 22.74it/s]
# epoch 010 | valid on 'valid' subset:  52% 136/262 [00:06<00:05, 22.56it/s]
# epoch 010 | valid on 'valid' subset:  53% 139/262 [00:06<00:05, 22.65it/s]
# epoch 010 | valid on 'valid' subset:  54% 142/262 [00:06<00:05, 23.00it/s]
# epoch 010 | valid on 'valid' subset:  55% 145/262 [00:06<00:05, 22.80it/s]
# epoch 010 | valid on 'valid' subset:  56% 148/262 [00:07<00:04, 23.12it/s]
# epoch 010 | valid on 'valid' subset:  58% 151/262 [00:07<00:04, 23.24it/s]
# epoch 010 | valid on 'valid' subset:  59% 154/262 [00:07<00:04, 22.78it/s]
# epoch 010 | valid on 'valid' subset:  60% 157/262 [00:07<00:04, 22.71it/s]
# epoch 010 | valid on 'valid' subset:  61% 160/262 [00:07<00:04, 21.00it/s]
# epoch 010 | valid on 'valid' subset:  62% 163/262 [00:07<00:04, 20.42it/s]
# epoch 010 | valid on 'valid' subset:  63% 166/262 [00:07<00:04, 19.57it/s]
# epoch 010 | valid on 'valid' subset:  64% 168/262 [00:08<00:04, 19.30it/s]
# epoch 010 | valid on 'valid' subset:  65% 170/262 [00:08<00:04, 18.97it/s]
# epoch 010 | valid on 'valid' subset:  66% 173/262 [00:08<00:04, 18.71it/s]
# epoch 010 | valid on 'valid' subset:  67% 175/262 [00:08<00:04, 18.35it/s]
# epoch 010 | valid on 'valid' subset:  68% 177/262 [00:08<00:04, 18.45it/s]
# epoch 010 | valid on 'valid' subset:  68% 179/262 [00:08<00:04, 18.02it/s]
# epoch 010 | valid on 'valid' subset:  69% 181/262 [00:08<00:04, 18.02it/s]
# epoch 010 | valid on 'valid' subset:  70% 183/262 [00:08<00:04, 18.10it/s]
# epoch 010 | valid on 'valid' subset:  71% 185/262 [00:08<00:04, 18.53it/s]
# epoch 010 | valid on 'valid' subset:  71% 187/262 [00:09<00:04, 18.48it/s]
# epoch 010 | valid on 'valid' subset:  72% 189/262 [00:09<00:03, 18.77it/s]
# epoch 010 | valid on 'valid' subset:  73% 191/262 [00:09<00:03, 18.52it/s]
# epoch 010 | valid on 'valid' subset:  74% 193/262 [00:09<00:03, 18.44it/s]
# epoch 010 | valid on 'valid' subset:  74% 195/262 [00:09<00:03, 18.63it/s]
# epoch 010 | valid on 'valid' subset:  75% 197/262 [00:09<00:03, 18.92it/s]
# epoch 010 | valid on 'valid' subset:  76% 199/262 [00:09<00:03, 17.85it/s]
# epoch 010 | valid on 'valid' subset:  77% 202/262 [00:09<00:03, 18.37it/s]
# epoch 010 | valid on 'valid' subset:  78% 205/262 [00:10<00:03, 18.62it/s]
# epoch 010 | valid on 'valid' subset:  79% 207/262 [00:10<00:02, 18.52it/s]
# epoch 010 | valid on 'valid' subset:  80% 210/262 [00:10<00:02, 18.98it/s]
# epoch 010 | valid on 'valid' subset:  81% 212/262 [00:10<00:02, 18.76it/s]
# epoch 010 | valid on 'valid' subset:  82% 214/262 [00:10<00:02, 18.47it/s]
# epoch 010 | valid on 'valid' subset:  82% 216/262 [00:10<00:02, 18.29it/s]
# epoch 010 | valid on 'valid' subset:  83% 218/262 [00:10<00:02, 18.58it/s]
# epoch 010 | valid on 'valid' subset:  84% 220/262 [00:10<00:02, 18.93it/s]
# epoch 010 | valid on 'valid' subset:  85% 222/262 [00:10<00:02, 18.89it/s]
# epoch 010 | valid on 'valid' subset:  85% 224/262 [00:11<00:02, 18.98it/s]
# epoch 010 | valid on 'valid' subset:  86% 226/262 [00:11<00:01, 18.82it/s]
# epoch 010 | valid on 'valid' subset:  87% 228/262 [00:11<00:01, 18.41it/s]
# epoch 010 | valid on 'valid' subset:  88% 230/262 [00:11<00:01, 18.77it/s]
# epoch 010 | valid on 'valid' subset:  89% 233/262 [00:11<00:01, 20.39it/s]
# epoch 010 | valid on 'valid' subset:  90% 236/262 [00:11<00:01, 21.58it/s]
# epoch 010 | valid on 'valid' subset:  91% 239/262 [00:11<00:01, 22.13it/s]
# epoch 010 | valid on 'valid' subset:  92% 242/262 [00:11<00:00, 22.58it/s]
# epoch 010 | valid on 'valid' subset:  94% 245/262 [00:11<00:00, 23.06it/s]
# epoch 010 | valid on 'valid' subset:  95% 248/262 [00:12<00:00, 23.78it/s]
# epoch 010 | valid on 'valid' subset:  96% 251/262 [00:12<00:00, 24.08it/s]
# epoch 010 | valid on 'valid' subset:  97% 254/262 [00:12<00:00, 24.43it/s]
# epoch 010 | valid on 'valid' subset:  98% 257/262 [00:12<00:00, 25.16it/s]
# epoch 010 | valid on 'valid' subset:  99% 260/262 [00:12<00:00, 25.48it/s]
#                                                                           2024-11-04 12:37:39 | INFO | valid | epoch 010 | valid on 'valid' subset | loss 11.847 | ppl 3683.42 | wps 58440.6 | wpb 2790.6 | bsz 90.7 | num_updates 7770
# 2024-11-04 12:37:39 | INFO | fairseq_cli.train | begin save checkpoint
# 2024-11-04 12:37:40 | INFO | fairseq.checkpoint_utils | saved checkpoint checkpoints-target-tok/checkpoint10.pt (epoch 10 @ 7770 updates, score 11.847) (writing took 1.1599852750005084 seconds)
# /content/drive/MyDrive/Research/eng-to-nde/optok4at/machineTranslation/optok/optok_nmt/unigramNLM.py:46: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(self.scoreModule(embed.weight.detach()).flatten())
# >>> DUMP LEARNED LM AS MLM
# 2024-11-04 12:37:40 | INFO | fairseq_cli.train | end of epoch 10 (average epoch stats below)
# 2024-11-04 12:37:40 | INFO | train | epoch 010 | loss 9.254 | ppl 610.53 | wps 2625.2 | ups 0.55 | wpb 4814.2 | bsz 115.6 | num_updates 7770 | lr 0.000107624 | gnorm 0.752 | train_wall 1406 | wall 14201
# epoch 011:   0% 0/777 [00:00<?, ?it/s]2024-11-04 12:37:40 | INFO | fairseq.trainer | begin training epoch 11
# 2024-11-04 13:01:09 | INFO | fairseq_cli.train | end of epoch 11 (average epoch stats below)
# 2024-11-04 13:01:09 | INFO | train | epoch 011 | loss 9.139 | ppl 563.9 | wps 2654.4 | ups 0.55 | wpb 4813.5 | bsz 115.6 | num_updates 8547 | lr 0.000102616 | gnorm 0.76 | train_wall 1404 | wall 15610
# epoch 012:   0% 0/777 [00:00<?, ?it/s]2024-11-04 13:01:09 | INFO | fairseq.trainer | begin training epoch 12
# 2024-11-04 13:24:38 | INFO | fairseq_cli.train | end of epoch 12 (average epoch stats below)
# 2024-11-04 13:24:38 | INFO | train | epoch 012 | loss 9.053 | ppl 531.32 | wps 2651.8 | ups 0.55 | wpb 4808.7 | bsz 115.6 | num_updates 9324 | lr 9.82472e-05 | gnorm 0.777 | train_wall 1404 | wall 17019
# epoch 013:   0% 0/777 [00:00<?, ?it/s]2024-11-04 13:24:38 | INFO | fairseq.trainer | begin training epoch 13
# 2024-11-04 13:48:12 | INFO | fairseq_cli.train | end of epoch 13 (average epoch stats below)
# 2024-11-04 13:48:12 | INFO | train | epoch 013 | loss 8.958 | ppl 497.29 | wps 2643.6 | ups 0.55 | wpb 4810.6 | bsz 115.6 | num_updates 10101 | lr 9.43928e-05 | gnorm 0.78 | train_wall 1409 | wall 18433
# epoch 014:   0% 0/777 [00:00<?, ?it/s]2024-11-04 13:48:12 | INFO | fairseq.trainer | begin training epoch 14
# 2024-11-04 14:11:53 | INFO | fairseq_cli.train | end of epoch 14 (average epoch stats below)
# 2024-11-04 14:11:53 | INFO | train | epoch 014 | loss 8.882 | ppl 471.83 | wps 2629.9 | ups 0.55 | wpb 4811.5 | bsz 115.6 | num_updates 10878 | lr 9.09592e-05 | gnorm 0.796 | train_wall 1416 | wall 19854
# epoch 015:   0% 0/777 [00:00<?, ?it/s]2024-11-04 14:11:53 | INFO | fairseq.trainer | begin training epoch 15
# 2024-11-04 14:35:29 | INFO | fairseq_cli.train | end of epoch 15 (average epoch stats below)
# 2024-11-04 14:35:29 | INFO | train | epoch 015 | loss 8.815 | ppl 450.26 | wps 2642.8 | ups 0.55 | wpb 4813.9 | bsz 115.6 | num_updates 11655 | lr 8.7875e-05 | gnorm 0.796 | train_wall 1410 | wall 21270
# epoch 016:   0% 0/777 [00:00<?, ?it/s]2024-11-04 14:35:29 | INFO | fairseq.trainer | begin training epoch 16
# 2024-11-04 14:58:59 | INFO | fairseq_cli.train | end of epoch 16 (average epoch stats below)
# 2024-11-04 14:58:59 | INFO | train | epoch 016 | loss 8.771 | ppl 436.92 | wps 2649 | ups 0.55 | wpb 4808.2 | bsz 115.6 | num_updates 12432 | lr 8.50846e-05 | gnorm 0.811 | train_wall 1405 | wall 22680
# epoch 017:   0% 0/777 [00:00<?, ?it/s]2024-11-04 14:58:59 | INFO | fairseq.trainer | begin training epoch 17
# 2024-11-04 15:22:32 | INFO | fairseq_cli.train | end of epoch 17 (average epoch stats below)
# 2024-11-04 15:22:32 | INFO | train | epoch 017 | loss 8.703 | ppl 416.76 | wps 2646.2 | ups 0.55 | wpb 4810.5 | bsz 115.6 | num_updates 13209 | lr 8.25441e-05 | gnorm 0.816 | train_wall 1407 | wall 24092
# epoch 018:   0% 0/777 [00:00<?, ?it/s]2024-11-04 15:22:32 | INFO | fairseq.trainer | begin training epoch 18
# 2024-11-04 15:46:03 | INFO | fairseq_cli.train | end of epoch 18 (average epoch stats below)
# 2024-11-04 15:46:03 | INFO | train | epoch 018 | loss 8.649 | ppl 401.34 | wps 2650.7 | ups 0.55 | wpb 4814.9 | bsz 115.6 | num_updates 13986 | lr 8.02185e-05 | gnorm 0.825 | train_wall 1407 | wall 25504
# epoch 019:   0% 0/777 [00:00<?, ?it/s]2024-11-04 15:46:03 | INFO | fairseq.trainer | begin training epoch 19
# 2024-11-04 16:09:37 | INFO | fairseq_cli.train | end of epoch 19 (average epoch stats below)
# 2024-11-04 16:09:37 | INFO | train | epoch 019 | loss 8.612 | ppl 391.21 | wps 2643.2 | ups 0.55 | wpb 4810.8 | bsz 115.6 | num_updates 14763 | lr 7.80789e-05 | gnorm 0.827 | train_wall 1409 | wall 26918
# epoch 020:   0% 0/777 [00:00<?, ?it/s]2024-11-04 16:09:37 | INFO | fairseq.trainer | begin training epoch 20
# epoch 020: 100% 776/777 [23:33<00:01,  1.81s/it, loss=8.464, ppl=353.06, wps=2675, ups=0.55, wpb=4881.9, bsz=120.4, num_updates=15500, lr=7.62001e-05, gnorm=0.817, train_wall=182, wall=28261]2024-11-04 16:33:13 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 020 | valid on 'valid' subset:   0% 0/262 [00:00<?, ?it/s]
# epoch 020 | valid on 'valid' subset:   0% 1/262 [00:00<01:05,  3.98it/s]
# epoch 020 | valid on 'valid' subset:   1% 2/262 [00:00<00:44,  5.87it/s]
# epoch 020 | valid on 'valid' subset:   1% 3/262 [00:00<00:39,  6.57it/s]
# epoch 020 | valid on 'valid' subset:   2% 5/262 [00:00<00:32,  7.96it/s]
# epoch 020 | valid on 'valid' subset:   3% 7/262 [00:00<00:28,  8.85it/s]
# epoch 020 | valid on 'valid' subset:   3% 9/262 [00:01<00:23, 10.85it/s]
# epoch 020 | valid on 'valid' subset:   4% 11/262 [00:01<00:19, 12.74it/s]
# epoch 020 | valid on 'valid' subset:   5% 13/262 [00:01<00:17, 14.45it/s]
# epoch 020 | valid on 'valid' subset:   6% 15/262 [00:01<00:16, 15.20it/s]
# epoch 020 | valid on 'valid' subset:   7% 18/262 [00:01<00:14, 17.32it/s]
# epoch 020 | valid on 'valid' subset:   8% 21/262 [00:01<00:13, 18.37it/s]
# epoch 020 | valid on 'valid' subset:   9% 24/262 [00:01<00:12, 19.20it/s]
# epoch 020 | valid on 'valid' subset:  10% 27/262 [00:01<00:11, 20.18it/s]
# epoch 020 | valid on 'valid' subset:  11% 30/262 [00:02<00:11, 20.81it/s]
# epoch 020 | valid on 'valid' subset:  13% 33/262 [00:02<00:11, 20.72it/s]
# epoch 020 | valid on 'valid' subset:  14% 36/262 [00:02<00:11, 20.35it/s]
# epoch 020 | valid on 'valid' subset:  15% 39/262 [00:02<00:10, 20.50it/s]
# epoch 020 | valid on 'valid' subset:  16% 42/262 [00:02<00:10, 20.41it/s]
# epoch 020 | valid on 'valid' subset:  17% 45/262 [00:02<00:10, 20.88it/s]
# epoch 020 | valid on 'valid' subset:  18% 48/262 [00:02<00:10, 21.17it/s]
# epoch 020 | valid on 'valid' subset:  19% 51/262 [00:03<00:10, 21.08it/s]
# epoch 020 | valid on 'valid' subset:  21% 54/262 [00:03<00:09, 21.14it/s]
# epoch 020 | valid on 'valid' subset:  22% 57/262 [00:03<00:09, 20.95it/s]
# epoch 020 | valid on 'valid' subset:  23% 60/262 [00:03<00:09, 20.77it/s]
# epoch 020 | valid on 'valid' subset:  24% 63/262 [00:03<00:09, 21.11it/s]
# epoch 020 | valid on 'valid' subset:  25% 66/262 [00:03<00:09, 21.22it/s]
# epoch 020 | valid on 'valid' subset:  26% 69/262 [00:03<00:08, 21.76it/s]
# epoch 020 | valid on 'valid' subset:  27% 72/262 [00:04<00:08, 21.47it/s]
# epoch 020 | valid on 'valid' subset:  29% 75/262 [00:04<00:08, 21.58it/s]
# epoch 020 | valid on 'valid' subset:  30% 78/262 [00:04<00:08, 21.06it/s]
# epoch 020 | valid on 'valid' subset:  31% 81/262 [00:04<00:08, 21.02it/s]
# epoch 020 | valid on 'valid' subset:  32% 84/262 [00:04<00:08, 21.22it/s]
# epoch 020 | valid on 'valid' subset:  33% 87/262 [00:04<00:08, 21.56it/s]
# epoch 020 | valid on 'valid' subset:  34% 90/262 [00:04<00:07, 21.78it/s]
# epoch 020 | valid on 'valid' subset:  35% 93/262 [00:05<00:07, 22.28it/s]
# epoch 020 | valid on 'valid' subset:  37% 96/262 [00:05<00:07, 21.23it/s]
# epoch 020 | valid on 'valid' subset:  38% 99/262 [00:05<00:07, 20.72it/s]
# epoch 020 | valid on 'valid' subset:  39% 102/262 [00:05<00:07, 21.21it/s]
# epoch 020 | valid on 'valid' subset:  40% 105/262 [00:05<00:07, 21.47it/s]
# epoch 020 | valid on 'valid' subset:  41% 108/262 [00:05<00:07, 21.97it/s]
# epoch 020 | valid on 'valid' subset:  42% 111/262 [00:05<00:07, 20.95it/s]
# epoch 020 | valid on 'valid' subset:  44% 114/262 [00:05<00:06, 21.55it/s]
# epoch 020 | valid on 'valid' subset:  45% 117/262 [00:06<00:06, 21.85it/s]
# epoch 020 | valid on 'valid' subset:  46% 120/262 [00:06<00:06, 22.06it/s]
# epoch 020 | valid on 'valid' subset:  47% 123/262 [00:06<00:06, 21.79it/s]
# epoch 020 | valid on 'valid' subset:  48% 126/262 [00:06<00:06, 22.08it/s]
# epoch 020 | valid on 'valid' subset:  49% 129/262 [00:06<00:05, 22.33it/s]
# epoch 020 | valid on 'valid' subset:  50% 132/262 [00:06<00:05, 22.87it/s]
# epoch 020 | valid on 'valid' subset:  52% 135/262 [00:06<00:05, 22.83it/s]
# epoch 020 | valid on 'valid' subset:  53% 138/262 [00:07<00:05, 22.38it/s]
# epoch 020 | valid on 'valid' subset:  54% 141/262 [00:07<00:05, 22.58it/s]
# epoch 020 | valid on 'valid' subset:  55% 144/262 [00:07<00:05, 22.80it/s]
# epoch 020 | valid on 'valid' subset:  56% 147/262 [00:07<00:05, 22.42it/s]
# epoch 020 | valid on 'valid' subset:  57% 150/262 [00:07<00:05, 22.04it/s]
# epoch 020 | valid on 'valid' subset:  58% 153/262 [00:07<00:04, 22.53it/s]
# epoch 020 | valid on 'valid' subset:  60% 156/262 [00:07<00:04, 22.63it/s]
# epoch 020 | valid on 'valid' subset:  61% 159/262 [00:07<00:04, 22.96it/s]
# epoch 020 | valid on 'valid' subset:  62% 162/262 [00:08<00:04, 23.28it/s]
# epoch 020 | valid on 'valid' subset:  63% 165/262 [00:08<00:04, 23.27it/s]
# epoch 020 | valid on 'valid' subset:  64% 168/262 [00:08<00:04, 23.17it/s]
# epoch 020 | valid on 'valid' subset:  65% 171/262 [00:08<00:03, 23.23it/s]
# epoch 020 | valid on 'valid' subset:  66% 174/262 [00:08<00:03, 22.99it/s]
# epoch 020 | valid on 'valid' subset:  68% 177/262 [00:08<00:03, 23.19it/s]
# epoch 020 | valid on 'valid' subset:  69% 180/262 [00:08<00:03, 23.02it/s]
# epoch 020 | valid on 'valid' subset:  70% 183/262 [00:09<00:03, 23.06it/s]
# epoch 020 | valid on 'valid' subset:  71% 186/262 [00:09<00:03, 23.46it/s]
# epoch 020 | valid on 'valid' subset:  72% 189/262 [00:09<00:03, 23.41it/s]
# epoch 020 | valid on 'valid' subset:  73% 192/262 [00:09<00:03, 23.11it/s]
# epoch 020 | valid on 'valid' subset:  74% 195/262 [00:09<00:02, 23.00it/s]
# epoch 020 | valid on 'valid' subset:  76% 198/262 [00:09<00:02, 23.48it/s]
# epoch 020 | valid on 'valid' subset:  77% 201/262 [00:09<00:02, 23.89it/s]
# epoch 020 | valid on 'valid' subset:  78% 204/262 [00:09<00:02, 23.82it/s]
# epoch 020 | valid on 'valid' subset:  79% 207/262 [00:10<00:02, 23.75it/s]
# epoch 020 | valid on 'valid' subset:  80% 210/262 [00:10<00:02, 23.92it/s]
# epoch 020 | valid on 'valid' subset:  81% 213/262 [00:10<00:02, 23.60it/s]
# epoch 020 | valid on 'valid' subset:  82% 216/262 [00:10<00:01, 23.50it/s]
# epoch 020 | valid on 'valid' subset:  84% 219/262 [00:10<00:01, 23.15it/s]
# epoch 020 | valid on 'valid' subset:  85% 222/262 [00:10<00:01, 23.29it/s]
# epoch 020 | valid on 'valid' subset:  86% 225/262 [00:10<00:01, 23.28it/s]
# epoch 020 | valid on 'valid' subset:  87% 228/262 [00:10<00:01, 23.30it/s]
# epoch 020 | valid on 'valid' subset:  88% 231/262 [00:11<00:01, 21.09it/s]
# epoch 020 | valid on 'valid' subset:  89% 234/262 [00:11<00:01, 20.03it/s]
# epoch 020 | valid on 'valid' subset:  90% 237/262 [00:11<00:01, 19.80it/s]
# epoch 020 | valid on 'valid' subset:  92% 240/262 [00:11<00:01, 19.44it/s]
# epoch 020 | valid on 'valid' subset:  92% 242/262 [00:11<00:01, 19.19it/s]
# epoch 020 | valid on 'valid' subset:  93% 244/262 [00:11<00:00, 19.29it/s]
# epoch 020 | valid on 'valid' subset:  94% 247/262 [00:11<00:00, 20.02it/s]
# epoch 020 | valid on 'valid' subset:  95% 250/262 [00:12<00:00, 19.82it/s]
# epoch 020 | valid on 'valid' subset:  97% 253/262 [00:12<00:00, 19.47it/s]
# epoch 020 | valid on 'valid' subset:  98% 256/262 [00:12<00:00, 20.08it/s]
# epoch 020 | valid on 'valid' subset:  99% 259/262 [00:12<00:00, 21.08it/s]
# epoch 020 | valid on 'valid' subset: 100% 262/262 [00:12<00:00, 21.50it/s]
#                                                                           2024-11-04 16:33:26 | INFO | valid | epoch 020 | valid on 'valid' subset | loss 10.882 | ppl 1887.23 | wps 58815 | wpb 2790.6 | bsz 90.7 | num_updates 15540 | best_loss 10.882
# 2024-11-04 16:33:26 | INFO | fairseq_cli.train | begin save checkpoint
# 2024-11-04 16:33:27 | INFO | fairseq.checkpoint_utils | saved checkpoint checkpoints-target-tok/checkpoint20.pt (epoch 20 @ 15540 updates, score 10.882) (writing took 1.4485443549965566 seconds)
# >>> DUMP LEARNED LM AS MLM
# 2024-11-04 16:33:27 | INFO | fairseq_cli.train | end of epoch 20 (average epoch stats below)
# 2024-11-04 16:33:27 | INFO | train | epoch 020 | loss 8.553 | ppl 375.66 | wps 2616.6 | ups 0.54 | wpb 4815.6 | bsz 115.6 | num_updates 15540 | lr 7.61019e-05 | gnorm 0.83 | train_wall 1410 | wall 28348
# epoch 021:   0% 0/777 [00:00<?, ?it/s]2024-11-04 16:33:27 | INFO | fairseq.trainer | begin training epoch 21
# 2024-11-04 16:56:58 | INFO | fairseq_cli.train | end of epoch 21 (average epoch stats below)
# 2024-11-04 16:56:58 | INFO | train | epoch 021 | loss 8.506 | ppl 363.47 | wps 2651.5 | ups 0.55 | wpb 4813.8 | bsz 115.6 | num_updates 16317 | lr 7.42679e-05 | gnorm 0.835 | train_wall 1405 | wall 29759
# epoch 022:   0% 0/777 [00:00<?, ?it/s]2024-11-04 16:56:58 | INFO | fairseq.trainer | begin training epoch 22
# 2024-11-04 17:20:31 | INFO | fairseq_cli.train | end of epoch 22 (average epoch stats below)
# 2024-11-04 17:20:31 | INFO | train | epoch 022 | loss 8.464 | ppl 353.13 | wps 2645.1 | ups 0.55 | wpb 4811.1 | bsz 115.6 | num_updates 17094 | lr 7.25604e-05 | gnorm 0.842 | train_wall 1408 | wall 31172
# epoch 023:   0% 0/777 [00:00<?, ?it/s]2024-11-04 17:20:31 | INFO | fairseq.trainer | begin training epoch 23
# 2024-11-04 17:44:01 | INFO | fairseq_cli.train | end of epoch 23 (average epoch stats below)
# 2024-11-04 17:44:01 | INFO | train | epoch 023 | loss 8.415 | ppl 341.37 | wps 2652.6 | ups 0.55 | wpb 4814.1 | bsz 115.6 | num_updates 17871 | lr 7.09654e-05 | gnorm 0.843 | train_wall 1405 | wall 32582
# epoch 024:   0% 0/777 [00:00<?, ?it/s]2024-11-04 17:44:01 | INFO | fairseq.trainer | begin training epoch 24
# 2024-11-04 18:07:21 | INFO | fairseq_cli.train | end of epoch 24 (average epoch stats below)
# 2024-11-04 18:07:21 | INFO | train | epoch 024 | loss 8.394 | ppl 336.46 | wps 2670.2 | ups 0.56 | wpb 4809.6 | bsz 115.6 | num_updates 18648 | lr 6.94713e-05 | gnorm 0.859 | train_wall 1394 | wall 33982
# epoch 025:   0% 0/777 [00:00<?, ?it/s]2024-11-04 18:07:21 | INFO | fairseq.trainer | begin training epoch 25
# 2024-11-04 18:30:31 | INFO | fairseq_cli.train | end of epoch 25 (average epoch stats below)
# 2024-11-04 18:30:31 | INFO | train | epoch 025 | loss 8.35 | ppl 326.35 | wps 2690 | ups 0.56 | wpb 4812.3 | bsz 115.6 | num_updates 19425 | lr 6.80676e-05 | gnorm 0.868 | train_wall 1385 | wall 35372
# epoch 026:   0% 0/777 [00:00<?, ?it/s]2024-11-04 18:30:31 | INFO | fairseq.trainer | begin training epoch 26
# 2024-11-04 18:54:05 | INFO | fairseq_cli.train | end of epoch 26 (average epoch stats below)
# 2024-11-04 18:54:05 | INFO | train | epoch 026 | loss 8.32 | ppl 319.64 | wps 2645.3 | ups 0.55 | wpb 4813.5 | bsz 115.6 | num_updates 20202 | lr 6.67458e-05 | gnorm 0.864 | train_wall 1409 | wall 36785
# epoch 027:   0% 0/777 [00:00<?, ?it/s]2024-11-04 18:54:05 | INFO | fairseq.trainer | begin training epoch 27
# 2024-11-04 19:17:32 | INFO | fairseq_cli.train | end of epoch 27 (average epoch stats below)
# 2024-11-04 19:17:32 | INFO | train | epoch 027 | loss 8.299 | ppl 314.95 | wps 2655.5 | ups 0.55 | wpb 4809.5 | bsz 115.6 | num_updates 20979 | lr 6.54981e-05 | gnorm 0.861 | train_wall 1402 | wall 38193
# epoch 028:   0% 0/777 [00:00<?, ?it/s]2024-11-04 19:17:32 | INFO | fairseq.trainer | begin training epoch 28
# 2024-11-04 19:41:12 | INFO | fairseq_cli.train | end of epoch 28 (average epoch stats below)
# 2024-11-04 19:41:12 | INFO | train | epoch 028 | loss 8.26 | ppl 306.62 | wps 2631.2 | ups 0.55 | wpb 4810.3 | bsz 115.6 | num_updates 21756 | lr 6.43179e-05 | gnorm 0.869 | train_wall 1415 | wall 39613
# epoch 029:   0% 0/777 [00:00<?, ?it/s]2024-11-04 19:41:12 | INFO | fairseq.trainer | begin training epoch 29
# 2024-11-04 20:04:42 | INFO | fairseq_cli.train | end of epoch 29 (average epoch stats below)
# 2024-11-04 20:04:42 | INFO | train | epoch 029 | loss 8.224 | ppl 298.95 | wps 2652.6 | ups 0.55 | wpb 4811.6 | bsz 115.6 | num_updates 22533 | lr 6.31992e-05 | gnorm 0.866 | train_wall 1404 | wall 41023
# epoch 030:   0% 0/777 [00:00<?, ?it/s]2024-11-04 20:04:42 | INFO | fairseq.trainer | begin training epoch 30
# epoch 030: 100% 776/777 [23:20<00:01,  1.82s/it, loss=8.178, ppl=289.63, wps=2673.7, ups=0.56, wpb=4800.3, bsz=116.4, num_updates=23300, lr=6.21503e-05, gnorm=0.845, train_wall=179, wall=42407]2024-11-04 20:28:04 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 030 | valid on 'valid' subset:   0% 0/262 [00:00<?, ?it/s]
# epoch 030 | valid on 'valid' subset:   0% 1/262 [00:00<00:38,  6.72it/s]
# epoch 030 | valid on 'valid' subset:   1% 3/262 [00:00<00:24, 10.41it/s]
# epoch 030 | valid on 'valid' subset:   2% 5/262 [00:00<00:20, 12.78it/s]
# epoch 030 | valid on 'valid' subset:   3% 7/262 [00:00<00:21, 12.08it/s]
# epoch 030 | valid on 'valid' subset:   3% 9/262 [00:00<00:21, 11.74it/s]
# epoch 030 | valid on 'valid' subset:   4% 11/262 [00:00<00:20, 12.17it/s]
# epoch 030 | valid on 'valid' subset:   5% 14/262 [00:01<00:17, 14.14it/s]
# epoch 030 | valid on 'valid' subset:   6% 16/262 [00:01<00:15, 15.38it/s]
# epoch 030 | valid on 'valid' subset:   7% 18/262 [00:01<00:15, 15.57it/s]
# epoch 030 | valid on 'valid' subset:   8% 20/262 [00:01<00:15, 16.06it/s]
# epoch 030 | valid on 'valid' subset:   8% 22/262 [00:01<00:14, 16.90it/s]
# epoch 030 | valid on 'valid' subset:   9% 24/262 [00:01<00:14, 16.21it/s]
# epoch 030 | valid on 'valid' subset:  10% 26/262 [00:01<00:14, 16.49it/s]
# epoch 030 | valid on 'valid' subset:  11% 28/262 [00:01<00:15, 15.58it/s]
# epoch 030 | valid on 'valid' subset:  11% 30/262 [00:02<00:14, 16.18it/s]
# epoch 030 | valid on 'valid' subset:  12% 32/262 [00:02<00:14, 15.52it/s]
# epoch 030 | valid on 'valid' subset:  13% 34/262 [00:02<00:14, 15.76it/s]
# epoch 030 | valid on 'valid' subset:  14% 36/262 [00:02<00:14, 15.21it/s]
# epoch 030 | valid on 'valid' subset:  15% 38/262 [00:02<00:14, 15.12it/s]
# epoch 030 | valid on 'valid' subset:  15% 40/262 [00:02<00:14, 15.25it/s]
# epoch 030 | valid on 'valid' subset:  16% 42/262 [00:02<00:14, 15.45it/s]
# epoch 030 | valid on 'valid' subset:  17% 44/262 [00:02<00:13, 15.59it/s]
# epoch 030 | valid on 'valid' subset:  18% 46/262 [00:03<00:13, 15.49it/s]
# epoch 030 | valid on 'valid' subset:  18% 48/262 [00:03<00:13, 16.01it/s]
# epoch 030 | valid on 'valid' subset:  19% 50/262 [00:03<00:13, 16.03it/s]
# epoch 030 | valid on 'valid' subset:  20% 52/262 [00:03<00:12, 16.25it/s]
# epoch 030 | valid on 'valid' subset:  21% 54/262 [00:03<00:13, 15.65it/s]
# epoch 030 | valid on 'valid' subset:  21% 56/262 [00:03<00:13, 15.64it/s]
# epoch 030 | valid on 'valid' subset:  22% 58/262 [00:03<00:12, 16.50it/s]
# epoch 030 | valid on 'valid' subset:  23% 60/262 [00:03<00:12, 16.04it/s]
# epoch 030 | valid on 'valid' subset:  24% 62/262 [00:04<00:11, 16.89it/s]
# epoch 030 | valid on 'valid' subset:  24% 64/262 [00:04<00:11, 17.02it/s]
# epoch 030 | valid on 'valid' subset:  25% 66/262 [00:04<00:11, 16.41it/s]
# epoch 030 | valid on 'valid' subset:  26% 68/262 [00:04<00:12, 16.14it/s]
# epoch 030 | valid on 'valid' subset:  27% 70/262 [00:04<00:12, 15.42it/s]
# epoch 030 | valid on 'valid' subset:  27% 72/262 [00:04<00:12, 15.52it/s]
# epoch 030 | valid on 'valid' subset:  29% 75/262 [00:04<00:10, 17.88it/s]
# epoch 030 | valid on 'valid' subset:  30% 78/262 [00:04<00:09, 19.18it/s]
# epoch 030 | valid on 'valid' subset:  31% 81/262 [00:05<00:08, 20.33it/s]
# epoch 030 | valid on 'valid' subset:  32% 84/262 [00:05<00:08, 20.89it/s]
# epoch 030 | valid on 'valid' subset:  33% 87/262 [00:05<00:08, 21.38it/s]
# epoch 030 | valid on 'valid' subset:  34% 90/262 [00:05<00:07, 21.58it/s]
# epoch 030 | valid on 'valid' subset:  35% 93/262 [00:05<00:07, 22.14it/s]
# epoch 030 | valid on 'valid' subset:  37% 96/262 [00:05<00:07, 22.44it/s]
# epoch 030 | valid on 'valid' subset:  38% 99/262 [00:05<00:07, 22.58it/s]
# epoch 030 | valid on 'valid' subset:  39% 102/262 [00:06<00:07, 22.41it/s]
# epoch 030 | valid on 'valid' subset:  40% 105/262 [00:06<00:06, 22.51it/s]
# epoch 030 | valid on 'valid' subset:  41% 108/262 [00:06<00:06, 22.92it/s]
# epoch 030 | valid on 'valid' subset:  42% 111/262 [00:06<00:06, 23.00it/s]
# epoch 030 | valid on 'valid' subset:  44% 114/262 [00:06<00:06, 22.74it/s]
# epoch 030 | valid on 'valid' subset:  45% 117/262 [00:06<00:06, 22.64it/s]
# epoch 030 | valid on 'valid' subset:  46% 120/262 [00:06<00:06, 23.22it/s]
# epoch 030 | valid on 'valid' subset:  47% 123/262 [00:06<00:05, 23.32it/s]
# epoch 030 | valid on 'valid' subset:  48% 126/262 [00:07<00:05, 23.42it/s]
# epoch 030 | valid on 'valid' subset:  49% 129/262 [00:07<00:05, 23.50it/s]
# epoch 030 | valid on 'valid' subset:  50% 132/262 [00:07<00:05, 23.69it/s]
# epoch 030 | valid on 'valid' subset:  52% 135/262 [00:07<00:05, 23.78it/s]
# epoch 030 | valid on 'valid' subset:  53% 138/262 [00:07<00:05, 23.46it/s]
# epoch 030 | valid on 'valid' subset:  54% 141/262 [00:07<00:05, 23.36it/s]
# epoch 030 | valid on 'valid' subset:  55% 144/262 [00:07<00:04, 23.69it/s]
# epoch 030 | valid on 'valid' subset:  56% 147/262 [00:07<00:04, 24.07it/s]
# epoch 030 | valid on 'valid' subset:  57% 150/262 [00:08<00:04, 24.06it/s]
# epoch 030 | valid on 'valid' subset:  58% 153/262 [00:08<00:04, 24.18it/s]
# epoch 030 | valid on 'valid' subset:  60% 156/262 [00:08<00:04, 24.08it/s]
# epoch 030 | valid on 'valid' subset:  61% 159/262 [00:08<00:04, 24.17it/s]
# epoch 030 | valid on 'valid' subset:  62% 162/262 [00:08<00:04, 24.44it/s]
# epoch 030 | valid on 'valid' subset:  63% 165/262 [00:08<00:04, 23.91it/s]
# epoch 030 | valid on 'valid' subset:  64% 168/262 [00:08<00:03, 24.20it/s]
# epoch 030 | valid on 'valid' subset:  65% 171/262 [00:08<00:03, 24.43it/s]
# epoch 030 | valid on 'valid' subset:  66% 174/262 [00:09<00:03, 23.89it/s]
# epoch 030 | valid on 'valid' subset:  68% 177/262 [00:09<00:03, 24.37it/s]
# epoch 030 | valid on 'valid' subset:  69% 180/262 [00:09<00:03, 24.50it/s]
# epoch 030 | valid on 'valid' subset:  70% 183/262 [00:09<00:03, 24.50it/s]
# epoch 030 | valid on 'valid' subset:  71% 186/262 [00:09<00:03, 24.64it/s]
# epoch 030 | valid on 'valid' subset:  72% 189/262 [00:09<00:03, 23.84it/s]
# epoch 030 | valid on 'valid' subset:  73% 192/262 [00:09<00:02, 24.02it/s]
# epoch 030 | valid on 'valid' subset:  74% 195/262 [00:09<00:02, 24.10it/s]
# epoch 030 | valid on 'valid' subset:  76% 198/262 [00:10<00:02, 24.57it/s]
# epoch 030 | valid on 'valid' subset:  77% 201/262 [00:10<00:02, 24.94it/s]
# epoch 030 | valid on 'valid' subset:  78% 204/262 [00:10<00:02, 24.74it/s]
# epoch 030 | valid on 'valid' subset:  79% 207/262 [00:10<00:02, 24.85it/s]
# epoch 030 | valid on 'valid' subset:  80% 210/262 [00:10<00:02, 24.78it/s]
# epoch 030 | valid on 'valid' subset:  81% 213/262 [00:10<00:01, 24.69it/s]
# epoch 030 | valid on 'valid' subset:  82% 216/262 [00:10<00:01, 24.17it/s]
# epoch 030 | valid on 'valid' subset:  84% 219/262 [00:10<00:01, 24.54it/s]
# epoch 030 | valid on 'valid' subset:  85% 222/262 [00:11<00:01, 24.81it/s]
# epoch 030 | valid on 'valid' subset:  86% 225/262 [00:11<00:01, 24.92it/s]
# epoch 030 | valid on 'valid' subset:  87% 228/262 [00:11<00:01, 24.90it/s]
# epoch 030 | valid on 'valid' subset:  88% 231/262 [00:11<00:01, 24.66it/s]
# epoch 030 | valid on 'valid' subset:  89% 234/262 [00:11<00:01, 24.85it/s]
# epoch 030 | valid on 'valid' subset:  90% 237/262 [00:11<00:01, 24.82it/s]
# epoch 030 | valid on 'valid' subset:  92% 240/262 [00:11<00:00, 24.69it/s]
# epoch 030 | valid on 'valid' subset:  93% 243/262 [00:11<00:00, 24.78it/s]
# epoch 030 | valid on 'valid' subset:  94% 246/262 [00:11<00:00, 24.72it/s]
# epoch 030 | valid on 'valid' subset:  95% 249/262 [00:12<00:00, 25.54it/s]
# epoch 030 | valid on 'valid' subset:  96% 252/262 [00:12<00:00, 26.02it/s]
# epoch 030 | valid on 'valid' subset:  97% 255/262 [00:12<00:00, 26.34it/s]
# epoch 030 | valid on 'valid' subset:  98% 258/262 [00:12<00:00, 27.02it/s]
# epoch 030 | valid on 'valid' subset: 100% 261/262 [00:12<00:00, 27.17it/s]
#                                                                           2024-11-04 20:28:17 | INFO | valid | epoch 030 | valid on 'valid' subset | loss 10.436 | ppl 1385.33 | wps 58720.2 | wpb 2790.6 | bsz 90.7 | num_updates 23310 | best_loss 10.436
# 2024-11-04 20:28:17 | INFO | fairseq_cli.train | begin save checkpoint
# 2024-11-04 20:28:18 | INFO | fairseq.checkpoint_utils | saved checkpoint checkpoints-target-tok/checkpoint30.pt (epoch 30 @ 23310 updates, score 10.436) (writing took 1.1446757660014555 seconds)
# >>> DUMP LEARNED LM AS MLM
# 2024-11-04 20:28:18 | INFO | fairseq_cli.train | end of epoch 30 (average epoch stats below)
# 2024-11-04 20:28:18 | INFO | train | epoch 030 | loss 8.191 | ppl 292.16 | wps 2639.5 | ups 0.55 | wpb 4810.6 | bsz 115.6 | num_updates 23310 | lr 6.2137e-05 | gnorm 0.876 | train_wall 1398 | wall 42439
# 2024-11-04 20:28:18 | INFO | fairseq_cli.train | done training in 42435.1 seconds
