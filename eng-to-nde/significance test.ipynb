# %% [markdown]
# ## Setting up the notebook

# %%
# !pip install sacrebleu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import sacrebleu
import os

# %%
# mounting google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
source_code = 'eng'
target_code = 'nde'

# %% [markdown]
# ## baseline: BPE

# %%
ref = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/test.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpe/trained_model/post_process_translations_test'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_test'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpeDROP/trained_model/post_process_translations_test'

# %%
# !sacrebleu $ref -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-nde/bpe/trained_model/post_process_translations_test'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nde/ulm/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nde/bpeDROP/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-nde/bpe/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 10.852994452488423,
#             "p_value": null,
#             "mean": 10.85002812258583,
#             "ci": 0.5309097528545905
#         }
# ...

# %%
ref1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref1.{target_code}'
ref2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref2.{target_code}'
ref3 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref3.{target_code}'
ref4 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref4.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpe/trained_model/post_process_translations_gtest'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_gtest'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/bpeDROP/trained_model/post_process_translations_gtest'

# %%
# !sacrebleu $ref1 $ref2 $ref3 $ref4 -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-nde/bpe/trained_model/post_process_translations_gtest'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nde/ulm/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nde/bpeDROP/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-nde/bpe/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 10.20278876455416,
#             "p_value": null,
#             "mean": 10.179820256971826,
#             "ci": 1.1640964648905845
#         }
# ...

# %% [markdown]
# ## baseline: ULM

# %%
ref = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/test.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_test'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulmSR/trained_model/post_process_translations_test'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/target-tok/trained_model/post_process_translations_test'

# %%
# !sacrebleu $ref -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-nde/ulm/trained_model/post_process_translations_test'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nde/ulmSR/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nde/target-tok/trained_model/post_process_translations_test' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-nde/ulm/trained_model/post_process_translations_test",
#         "BLEU": {
#             "score": 11.260238509089215,
#             "p_value": null,
#             "mean": 11.257933267355321,
#             "ci": 0.5562940002259609
#         }
# ...

# %%
ref1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref1.{target_code}'
ref2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref2.{target_code}'
ref3 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref3.{target_code}'
ref4 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/cleaned-data/ref4.{target_code}'

# %%
baseline = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulm/trained_model/post_process_translations_gtest'
s1 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/ulmSR/trained_model/post_process_translations_gtest'
s2 = f'/content/drive/MyDrive/Research/eng-to-{target_code}/target-tok/trained_model/post_process_translations_gtest'

# %%
# !sacrebleu $ref1 $ref2 $ref3 $ref4 -i $baseline $s1 $s2 -m bleu --smooth-method none --paired-bs
# Out:
# sacreBLEU: Found 3 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: /content/drive/MyDrive/Research/eng-to-nde/ulm/trained_model/post_process_translations_gtest'
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nde/ulmSR/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for '/content/drive/MyDrive/Research/eng-to-nde/target-tok/trained_model/post_process_translations_gtest' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# [
#     {
#         "system": "Baseline: /content/drive/MyDrive/Research/eng-to-nde/ulm/trained_model/post_process_translations_gtest",
#         "BLEU": {
#             "score": 9.586161922670332,
#             "p_value": null,
#             "mean": 9.56460334991042,
#             "ci": 1.091779432119841
#         }
# ...
